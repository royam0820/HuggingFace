# %% [markdown]
# <a href="https://colab.research.google.com/github/royam0820/HuggingFace/blob/main/amr_dataset_generate_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.youtube.com/watch?v=z2QE12p3kMM

# %% [markdown]
# # Setup

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Why LLM Fine-Tuning?
#
# Fine-tuning of LLMs is the conventional method that retrains all model parameters for a specific task or domain. Fine-tuning a Large Language Model (LLM) is beneficial for several reasons:
#
# - **Domain Specificity**: General-purpose language models are trained on a wide variety of data and are not specialized in any particular domain. Fine-tuning allows you to adapt the model to specific industries, topics, or types of language, such as medical terminology, legal jargon, or technical language.
#
# - **Improved Accuracy**: Fine-tuning on a specific dataset can improve the model’s performance on tasks related to that data. This could mean more accurate classifications, better sentiment analysis, or more relevant generated text.
#
# - **Resource Efficiency**: Fine-tuning only a subset of the model’s parameters can be more computationally efficient than training a new model from scratch. This can be particularly important when computational resources are limited.
#
# - **Data Privacy**: If you have sensitive or proprietary data, fine-tuning a pre-trained model on your own infrastructure allows you to benefit from the capabilities of large language models without sharing your data externally.
#
# - **Task Adaptation**: General-purpose language models are not optimized for specific tasks like question-answering, summarization, or translation. Fine-tuning can adapt the model for these specialized tasks.
#
# - **Contextual Understanding**: Fine-tuning can help the model better understand the context in which it will be used, making it more effective at generating appropriate and useful responses.
#
# - **Reduced Training Time**: Starting with a pre-trained model and fine-tuning it for a specific task can be much faster than training a model from scratch.
#
# - **Avoid Overfitting**: When you have a small dataset, training a large model from scratch can lead to overfitting. Fine-tuning can mitigate this risk, as the model has already learned general language features from a large dataset and only needs to adapt to the specificities of the new data.
#
# - **Leverage Pre-trained Features**: Large language models trained on extensive datasets have already learned a wide array of features, from basic syntax and grammar to high-level semantic understanding. Fine-tuning allows you to leverage these features for your specific application.
#
# - **Customization**: Fine-tuning allows you to tailor the model’s behavior to specific requirements, such as generating text in a particular style, tone, or format.
#
# In summary, fine-tuning a large language model allows you to customize its capabilities for specific tasks, domains, or datasets, improving its performance and making it more applicable to your particular needs.

# %%
# getting from Google drive the llm fine-tuned
# !unzip /content/drive/MyDrive/llm_tuning/llama2-MJ-prompts.zip
# Out:
# Archive:  /content/drive/MyDrive/llm_tuning/llama2-MJ-prompts.zip
#    creating: content/llama2-MJ-prompts/
#  extracting: content/llama2-MJ-prompts/added_tokens.json
#   inflating: content/llama2-MJ-prompts/adapter_model.bin
#   inflating: content/llama2-MJ-prompts/tokenizer.model
#   inflating: content/llama2-MJ-prompts/special_tokens_map.json
#    creating: content/llama2-MJ-prompts/checkpoint-7/
#  extracting: content/llama2-MJ-prompts/checkpoint-7/added_tokens.json
#   inflating: content/llama2-MJ-prompts/checkpoint-7/adapter_model.bin
#   inflating: content/llama2-MJ-prompts/checkpoint-7/tokenizer.model
#   inflating: content/llama2-MJ-prompts/checkpoint-7/trainer_state.json
#   inflating: content/llama2-MJ-prompts/checkpoint-7/special_tokens_map.json
#   inflating: content/llama2-MJ-prompts/checkpoint-7/rng_state.pth
#   inflating: content/llama2-MJ-prompts/checkpoint-7/pytorch_model.bin
#   inflating: content/llama2-MJ-prompts/checkpoint-7/README.md
#   inflating: content/llama2-MJ-prompts/checkpoint-7/training_args.bin
#   inflating: content/llama2-MJ-prompts/checkpoint-7/tokenizer.json
#   inflating: content/llama2-MJ-prompts/checkpoint-7/tokenizer_config.json
#   inflating: content/llama2-MJ-prompts/checkpoint-7/adapter_config.json
#   inflating: content/llama2-MJ-prompts/checkpoint-7/optimizer.pt
#   inflating: content/llama2-MJ-prompts/checkpoint-7/scheduler.pt
#   inflating: content/llama2-MJ-prompts/training_params.json
#   inflating: content/llama2-MJ-prompts/README.md
#    creating: content/llama2-MJ-prompts/runs/
#    creating: content/llama2-MJ-prompts/runs/Oct21_09-22-30_f5ea7e9d9d97/
#   inflating: content/llama2-MJ-prompts/runs/Oct21_09-22-30_f5ea7e9d9d97/events.out.tfevents.1697880151.f5ea7e9d9d97.2610.0
#   inflating: content/llama2-MJ-prompts/training_args.bin
#   inflating: content/llama2-MJ-prompts/tokenizer.json
#   inflating: content/llama2-MJ-prompts/tokenizer_config.json
#   inflating: content/llama2-MJ-prompts/adapter_config.json

# %% [markdown]
# # GPT4 - Code interpreter - Dataset creation
#
# https://chat.openai.com/share/5380107c-821d-4849-993b-938fc8545268
#
# The goal of the dataset we are going to create is to ask ChatGPT to give us a prompt for an AI image generator based on a concept.
#
# Below is the prompt
# ```
# vv create a dataset that contains concept-prompt pair. For each of the concepts like "A person walking in the rain" create a detailed description that can be used by an AI image generator to create images.
# ```
#
# Based on the prompt example above, ChatGPT will give you several records to satisfy your request. The dataset generated contains two fields:
# - the `concept` and
# - the `description`
#
# To complete the dataset for the training of a language model, you need to request ChatGPT to add a column `text`
#
#
#
#
# - to provide the user with a concept regarding a dataset making base on two fields :
# - concept
# - description
#
# In your prompt, you make sure to give the language model an example of what you want, so that the language can replicate your demand by providing many example rows.
#
# ```
# vv create a dataset that contains concept-prompt pair. For each of the concepts like "A person walking in the rain" create a detailed description that can be used by an AI image generator to create images.
# ```
#
# You can repeat this process several times, so that you generate at least 300 rows for the dataset so that the model can learn during training.
#
# Then, you need to add an additional column called `text` that will have a specific format for the LLM with the tokens ###Human and ###Assistant:
#
# ```
# create another column called text which follows the following structure:
# text=f"###Human:\ngenerate a midjourney prompt for {concept}\n\n###Assistant:\n{description}"
# ```
# The added `text` column will hold the concept and description, with the tokens identified as ### . The model fine-tuning will be based  on this column `text`.
#
# Below is an example of a generated output:
#
# ```
# ###Human: generate a midjourney prompt for A sunset over the mountains ###Assistant: The sun is setting behind jagged mountain peaks. The sky is filled with shades of orange, pink, and purple, casting a warm glow on the mountains. Clouds lightly scattered, allowing the colors to shine through.
# ```
#
# This dataset creation steps will give you a csv file called `train`, with encoding in `utf-8`.
#
#
# ```
# df.to_csv('train.csv', encoding='utf-8', index=False)
# ```
#
#
#
# Now we are are ready for fine-tuning a large language model.

# %% [markdown]
# ### Issue with the train.csv file
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x89 in position 18905: invalid start byte

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv',  encoding='unicode_escape')

# %%
df.to_csv('train.csv', encoding='utf-8', index=False)

# %%
df=pd.read_csv('train.csv')

# %%
df.text[0]
# Out:
# '###Human:\n\ngenerate a midjourney prompt for A person walking in the rain\n\n####Assistant:\nA young adult wearing a navy-blue raincoat and matching rain boots walks on a wet cobblestone street. Raindrops create ripples in the puddles. They hold a red umbrella that shields them from the pouring rain. Their face is relaxed, enjoying the rainfall.'

# %% [markdown]
# NB:  LINKS:
#
# - autotrain: https://huggingface.co/autotrain
# - autotrain GitHub: https://github.com/huggingface/autotr...

# %% [markdown]
# # Training with autotrain-advanced
# 🤗 AutoTrain is a no-code tool for training state-of-the-art models for Natural Language Processing (NLP) tasks, for Computer Vision (CV) tasks, and for Speech tasks and even for Tabular tasks. It is built on top of the awesome tools developed by the Hugging Face team, and it is designed to be easy to use.
#
# [Autotrain](https://huggingface.co/docs/autotrain/index)

# %% [markdown]
# ## Autotrain Help

# %%
# #autotrain help
# !autotrain llm --help
# Out:
# usage: autotrain <command> [<args>] llm [-h] [--train] [--deploy] [--inference]
#                                         [--data_path DATA_PATH] [--train_split TRAIN_SPLIT]
#                                         [--valid_split VALID_SPLIT] [--text_column TEXT_COLUMN]
#                                         [--rejected_text_column REJECTED_TEXT_COLUMN]
#                                         [--model MODEL] [--learning_rate LEARNING_RATE]
#                                         [--num_train_epochs NUM_TRAIN_EPOCHS]
#                                         [--train_batch_size TRAIN_BATCH_SIZE]
#                                         [--warmup_ratio WARMUP_RATIO]
#                                         [--gradient_accumulation_steps GRADIENT_ACCUMULATION_STEPS]
#                                         [--optimizer OPTIMIZER] [--scheduler SCHEDULER]
#                                         [--weight_decay WEIGHT_DECAY]
#                                         [--max_grad_norm MAX_GRAD_NORM] [--seed SEED]
#                                         [--add_eos_token] [--block_size BLOCK_SIZE] [--use_peft]
#                                         [--lora_r LORA_R] [--lora_alpha LORA_ALPHA]
#                                         [--lora_dropout LORA_DROPOUT]
#                                         [--logging_steps LOGGING_STEPS]
#                                         [--project_name PROJECT_NAME]
#                                         [--evaluation_strategy EVALUATION_STRATEGY]
#                                         [--save_total_limit SAVE_TOTAL_LIMIT]
#                                         [--save_strategy SAVE_STRATEGY] [--auto_find_batch_size]
#                                         [--fp16] [--push_to_hub] [--use_int8]
#                                         [--model_max_length MODEL_MAX_LENGTH] [--repo_id REPO_ID]
#                                         [--use_int4] [--trainer TRAINER]
#                                         [--target_modules TARGET_MODULES] [--merge_adapter]
#                                         [--token TOKEN] [--backend BACKEND] [--username USERNAME]
#                                         [--use_flash_attention_2]
#                                         [--disable_gradient_checkpointing]
#
# ✨ Run AutoTrain LLM
#
# options:
#   -h, --help            show this help message and exit
#   --train               Train the model
#   --deploy              Deploy the model
#   --inference           Run inference
#   --data_path DATA_PATH, --data-path DATA_PATH
#                         Train dataset to use
#   --train_split TRAIN_SPLIT, --train-split TRAIN_SPLIT
#                         Test dataset split to use
#   --valid_split VALID_SPLIT, --valid-split VALID_SPLIT
#                         Validation dataset split to use
#   --text_column TEXT_COLUMN, --text-column TEXT_COLUMN
#                         Text column to use
#   --rejected_text_column REJECTED_TEXT_COLUMN, --rejected-text-column REJECTED_TEXT_COLUMN
#                         Rejected text column to use
#   --model MODEL         Model to use
#   --learning_rate LEARNING_RATE, --lr LEARNING_RATE, --learning-rate LEARNING_RATE
#                         Learning rate to use
#   --num_train_epochs NUM_TRAIN_EPOCHS, --epochs NUM_TRAIN_EPOCHS
#                         Number of training epochs to use
#   --train_batch_size TRAIN_BATCH_SIZE, --train-batch-size TRAIN_BATCH_SIZE, --batch-size TRAIN_BATCH_SIZE
#                         Training batch size to use
#   --warmup_ratio WARMUP_RATIO, --warmup-ratio WARMUP_RATIO
#                         Warmup proportion to use
#   --gradient_accumulation_steps GRADIENT_ACCUMULATION_STEPS, --gradient-accumulation-steps GRADIENT_ACCUMULATION_STEPS, --gradient-accumulation GRADIENT_ACCUMULATION_STEPS
#                         Gradient accumulation steps to use
#   --optimizer OPTIMIZER
#                         Optimizer to use
#   --scheduler SCHEDULER
#                         Scheduler to use
#   --weight_decay WEIGHT_DECAY, --weight-decay WEIGHT_DECAY
#                         Weight decay to use
#   --max_grad_norm MAX_GRAD_NORM, --max-grad-norm MAX_GRAD_NORM
#                         Max gradient norm to use
#   --seed SEED           Seed to use
#   --add_eos_token, --add-eos-token
#                         Add EOS token to use
#   --block_size BLOCK_SIZE, --block-size BLOCK_SIZE
#                         Block size to use
#   --use_peft, --use-peft
#                         Use PEFT to use
#   --lora_r LORA_R, --lora-r LORA_R
#                         Lora r to use
#   --lora_alpha LORA_ALPHA, --lora-alpha LORA_ALPHA
#                         Lora alpha to use
#   --lora_dropout LORA_DROPOUT, --lora-dropout LORA_DROPOUT
#                         Lora dropout to use
#   --logging_steps LOGGING_STEPS, --logging-steps LOGGING_STEPS
#                         Logging steps to use
#   --project_name PROJECT_NAME, --project-name PROJECT_NAME
#                         Output directory
#   --evaluation_strategy EVALUATION_STRATEGY, --evaluation-strategy EVALUATION_STRATEGY
#                         Evaluation strategy to use
#   --save_total_limit SAVE_TOTAL_LIMIT, --save-total-limit SAVE_TOTAL_LIMIT
#                         Save total limit to use
#   --save_strategy SAVE_STRATEGY, --save-strategy SAVE_STRATEGY
#                         Save strategy to use
#   --auto_find_batch_size, --auto-find-batch-size
#                         Auto find batch size True/False
#   --fp16                FP16 True/False
#   --push_to_hub, --push-to-hub
#                         Push to hub True/False. In case you want to push the trained model to
#                         huggingface hub
#   --use_int8, --use-int8
#                         Use int8 True/False
#   --model_max_length MODEL_MAX_LENGTH, --max-len MODEL_MAX_LENGTH, --max-length MODEL_MAX_LENGTH
#                         Model max length to use
#   --repo_id REPO_ID, --repo-id REPO_ID
#                         Repo id for hugging face hub. Format is username/repo_name
#   --use_int4, --use-int4
#                         Use int4 True/False
#   --trainer TRAINER     Trainer type to use
#   --target_modules TARGET_MODULES, --target-modules TARGET_MODULES
#                         Target modules to use
#   --merge_adapter, --merge-adapter
#                         Use this flag to merge PEFT adapter with the model
#   --token TOKEN         Hugingface token to use
#   --backend BACKEND     Backend to use: default or spaces. Spaces backend requires push_to_hub and
#                         repo_id
#   --username USERNAME   Huggingface username to use
#   --use_flash_attention_2, --use-flash-attention-2, --use-fa2
#                         Use flash attention 2
#   --disable_gradient_checkpointing, --disable-gradient-checkpointing, --disable-gc
#                         Disable gradient checkpointing

# %% [markdown]
# ## AutoTrain Setup

# %%
# !pip install -U autotrain-advanced
# !pip install -U huggingface_hub
# Out:
# Collecting autotrain-advanced
#   Downloading autotrain_advanced-0.6.41-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.7/128.7 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: albumentations==1.3.1 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (1.3.1)
# Collecting codecarbon==2.2.3 (from autotrain-advanced)
#   Downloading codecarbon-2.2.3-py3-none-any.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.1/174.1 kB 14.1 MB/s eta 0:00:00
# Collecting datasets[vision]~=2.14.0 (from autotrain-advanced)
#   Downloading datasets-2.14.6-py3-none-any.whl (493 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 46.0 MB/s eta 0:00:00
# Collecting evaluate==0.3.0 (from autotrain-advanced)
#   Downloading evaluate-0.3.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 10.3 MB/s eta 0:00:00
# Collecting ipadic==1.0.0 (from autotrain-advanced)
#   Downloading ipadic-1.0.0.tar.gz (13.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 87.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jiwer==3.0.2 (from autotrain-advanced)
#   Downloading jiwer-3.0.2-py3-none-any.whl (21 kB)
# Collecting joblib==1.3.1 (from autotrain-advanced)
#   Downloading joblib-1.3.1-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 34.6 MB/s eta 0:00:00
# Collecting loguru==0.7.0 (from autotrain-advanced)
#   Downloading loguru-0.7.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (1.5.3)
# Collecting optuna==3.3.0 (from autotrain-advanced)
#   Downloading optuna-3.3.0-py3-none-any.whl (404 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.2/404.2 kB 44.5 MB/s eta 0:00:00
# Collecting Pillow==10.0.0 (from autotrain-advanced)
#   Downloading Pillow-10.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 94.1 MB/s eta 0:00:00
# Collecting protobuf==4.23.4 (from autotrain-advanced)
#   Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 35.0 MB/s eta 0:00:00
# Collecting pydantic==1.10.11 (from autotrain-advanced)
#   Downloading pydantic-1.10.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 105.9 MB/s eta 0:00:00
# Collecting sacremoses==0.0.53 (from autotrain-advanced)
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 76.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting scikit-learn==1.3.0 (from autotrain-advanced)
#   Downloading scikit_learn-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 77.7 MB/s eta 0:00:00
# Collecting sentencepiece==0.1.99 (from autotrain-advanced)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 88.4 MB/s eta 0:00:00
# Collecting tqdm==4.65.0 (from autotrain-advanced)
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 10.2 MB/s eta 0:00:00
# Collecting werkzeug==2.3.6 (from autotrain-advanced)
#   Downloading Werkzeug-2.3.6-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 31.5 MB/s eta 0:00:00
# Collecting xgboost==1.7.6 (from autotrain-advanced)
#   Downloading xgboost-1.7.6-py3-none-manylinux2014_x86_64.whl (200.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.3/200.3 MB 5.2 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.16.4 (from autotrain-advanced)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 36.1 MB/s eta 0:00:00
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (2.31.0)
# Collecting gradio==3.41.0 (from autotrain-advanced)
#   Downloading gradio-3.41.0-py3-none-any.whl (20.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 62.6 MB/s eta 0:00:00
# Collecting einops==0.6.1 (from autotrain-advanced)
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.7 MB/s eta 0:00:00
# Collecting invisible-watermark==0.2.0 (from autotrain-advanced)
#   Downloading invisible_watermark-0.2.0-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 97.7 MB/s eta 0:00:00
# Collecting packaging==23.1 (from autotrain-advanced)
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from autotrain-advanced) (2.14.1)
# Collecting peft (from autotrain-advanced)
#   Downloading peft-0.5.0-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 14.2 MB/s eta 0:00:00
# Collecting trl (from autotrain-advanced)
#   Downloading trl-0.7.2-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.0/124.0 kB 15.7 MB/s eta 0:00:00
# Collecting tiktoken (from autotrain-advanced)
#   Downloading tiktoken-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 98.5 MB/s eta 0:00:00
# Collecting transformers (from autotrain-advanced)
#   Downloading transformers-4.34.1-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 98.4 MB/s eta 0:00:00
# Collecting accelerate (from autotrain-advanced)
#   Downloading accelerate-0.24.0-py3-none-any.whl (260 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 32.7 MB/s eta 0:00:00
# Collecting diffusers==0.21.4 (from autotrain-advanced)
#   Downloading diffusers-0.21.4-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 90.7 MB/s eta 0:00:00
# Collecting bitsandbytes (from autotrain-advanced)
#   Downloading bitsandbytes-0.41.1-py3-none-any.whl (92.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.1->autotrain-advanced) (1.23.5)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.1->autotrain-advanced) (1.11.3)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.1->autotrain-advanced) (0.19.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.1->autotrain-advanced) (6.0.1)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.1->autotrain-advanced) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.1->autotrain-advanced) (4.8.1.78)
# Collecting arrow (from codecarbon==2.2.3->autotrain-advanced)
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 9.2 MB/s eta 0:00:00
# Collecting pynvml (from codecarbon==2.2.3->autotrain-advanced)
#   Downloading pynvml-11.5.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from codecarbon==2.2.3->autotrain-advanced) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from codecarbon==2.2.3->autotrain-advanced) (9.0.0)
# Collecting fuzzywuzzy (from codecarbon==2.2.3->autotrain-advanced)
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from codecarbon==2.2.3->autotrain-advanced) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.4->autotrain-advanced) (3.12.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.4->autotrain-advanced) (6.8.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.21.4->autotrain-advanced) (2023.6.3)
# Collecting safetensors>=0.3.1 (from diffusers==0.21.4->autotrain-advanced)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 89.6 MB/s eta 0:00:00
# Collecting dill (from evaluate==0.3.0->autotrain-advanced)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate==0.3.0->autotrain-advanced) (3.4.1)
# Collecting multiprocess (from evaluate==0.3.0->autotrain-advanced)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate==0.3.0->autotrain-advanced) (2023.6.0)
# Collecting responses<0.19 (from evaluate==0.3.0->autotrain-advanced)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio==3.41.0->autotrain-advanced)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (4.2.2)
# Collecting fastapi (from gradio==3.41.0->autotrain-advanced)
#   Downloading fastapi-0.104.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 13.8 MB/s eta 0:00:00
# Collecting ffmpy (from gradio==3.41.0->autotrain-advanced)
#   Downloading ffmpy-0.3.1.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.5.0 (from gradio==3.41.0->autotrain-advanced)
#   Downloading gradio_client-0.5.0-py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 38.6 MB/s eta 0:00:00
# Collecting httpx (from gradio==3.41.0->autotrain-advanced)
#   Downloading httpx-0.25.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (6.1.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (3.7.1)
# Collecting orjson~=3.0 (from gradio==3.41.0->autotrain-advanced)
#   Downloading orjson-3.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 6.8 MB/s eta 0:00:00
# Collecting pydub (from gradio==3.41.0->autotrain-advanced)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart (from gradio==3.41.0->autotrain-advanced)
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 6.2 MB/s eta 0:00:00
# Collecting semantic-version~=2.0 (from gradio==3.41.0->autotrain-advanced)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.41.0->autotrain-advanced) (4.5.0)
# Collecting uvicorn>=0.14.0 (from gradio==3.41.0->autotrain-advanced)
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 9.6 MB/s eta 0:00:00
# Collecting websockets<12.0,>=10.0 (from gradio==3.41.0->autotrain-advanced)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from invisible-watermark==0.2.0->autotrain-advanced) (1.4.1)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.10/dist-packages (from invisible-watermark==0.2.0->autotrain-advanced) (4.8.0.76)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from invisible-watermark==0.2.0->autotrain-advanced) (2.1.0+cu118)
# Collecting rapidfuzz==2.13.7 (from jiwer==3.0.2->autotrain-advanced)
#   Downloading rapidfuzz-2.13.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 100.7 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna==3.3.0->autotrain-advanced)
#   Downloading alembic-1.12.0-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.0/226.0 kB 32.2 MB/s eta 0:00:00
# Collecting cmaes>=0.10.0 (from optuna==3.3.0->autotrain-advanced)
#   Downloading cmaes-0.10.0-py3-none-any.whl (29 kB)
# Collecting colorlog (from optuna==3.3.0->autotrain-advanced)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna==3.3.0->autotrain-advanced) (2.0.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->autotrain-advanced) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->autotrain-advanced) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->autotrain-advanced) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->autotrain-advanced) (2023.7.22)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from sacremoses==0.0.53->autotrain-advanced) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.3.0->autotrain-advanced) (3.2.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]~=2.14.0->autotrain-advanced) (9.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets[vision]~=2.14.0->autotrain-advanced) (3.8.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->autotrain-advanced) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->autotrain-advanced) (2023.3.post1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (1.59.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (3.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->autotrain-advanced) (0.7.1)
# Collecting tokenizers<0.15,>=0.14 (from transformers->autotrain-advanced)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 62.5 MB/s eta 0:00:00
# Collecting tyro>=0.5.7 (from trl->autotrain-advanced)
#   Downloading tyro-0.5.10-py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 14.9 MB/s eta 0:00:00
# Collecting Mako (from alembic>=1.5.0->optuna==3.3.0->autotrain-advanced)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (4.19.1)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (0.12.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]~=2.14.0->autotrain-advanced) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->autotrain-advanced) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->autotrain-advanced) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->autotrain-advanced) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->autotrain-advanced) (1.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.41.0->autotrain-advanced) (3.1.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.1->autotrain-advanced) (3.2)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.1->autotrain-advanced) (2.31.5)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.1->autotrain-advanced) (2023.9.26)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna==3.3.0->autotrain-advanced) (3.0.0)
# Collecting huggingface-hub>=0.16.4 (from autotrain-advanced)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 36.3 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark==0.2.0->autotrain-advanced) (1.12)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark==0.2.0->autotrain-advanced) (2.1.0)
# Collecting docstring-parser>=0.14.1 (from tyro>=0.5.7->trl->autotrain-advanced)
#   Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.7->trl->autotrain-advanced) (13.6.0)
# Collecting shtab>=1.5.6 (from tyro>=0.5.7->trl->autotrain-advanced)
#   Downloading shtab-1.6.4-py3-none-any.whl (13 kB)
# Collecting h11>=0.8 (from uvicorn>=0.14.0->gradio==3.41.0->autotrain-advanced)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.6 MB/s eta 0:00:00
# Collecting types-python-dateutil>=2.8.10 (from arrow->codecarbon==2.2.3->autotrain-advanced)
#   Downloading types_python_dateutil-2.8.19.14-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio==3.41.0->autotrain-advanced) (3.7.1)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi->gradio==3.41.0->autotrain-advanced)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 11.2 MB/s eta 0:00:00
# Collecting typing-extensions~=4.0 (from gradio==3.41.0->autotrain-advanced)
#   Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Collecting httpcore<0.19.0,>=0.18.0 (from httpx->gradio==3.41.0->autotrain-advanced)
#   Downloading httpcore-0.18.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.41.0->autotrain-advanced) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.21.4->autotrain-advanced) (3.17.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio==3.41.0->autotrain-advanced) (1.1.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.41.0->autotrain-advanced) (0.10.6)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->autotrain-advanced) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->autotrain-advanced) (3.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.7->trl->autotrain-advanced) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.7->trl->autotrain-advanced) (2.16.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->invisible-watermark==0.2.0->autotrain-advanced) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.7->trl->autotrain-advanced) (0.1.2)
# Building wheels for collected packages: ipadic, sacremoses, ffmpy
#   Building wheel for ipadic (setup.py) ... done
#   Created wheel for ipadic: filename=ipadic-1.0.0-py3-none-any.whl size=13556703 sha256=a4aeabe7404373c3110142a8723138393f8b8ce4f28d9573a46af93edb03e989
#   Stored in directory: /root/.cache/pip/wheels/5b/ea/e3/2f6e0860a327daba3b030853fce4483ed37468bbf1101c59c3
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895241 sha256=54d6a630cf0917525c8f29bfb6b0b8d914ffb9858062f76cf0a236df1134c9f4
#   Stored in directory: /root/.cache/pip/wheels/00/24/97/a2ea5324f36bc626e1ea0267f33db6aa80d157ee977e9e42fb
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.1-py3-none-any.whl size=5579 sha256=5757fcb2b8c7aa745c7e07155a41dbc7d0bc13eb87eec84fa1bfe7b967d571fc
#   Stored in directory: /root/.cache/pip/wheels/01/a6/d1/1c0828c304a4283b2c1639a09ad86f83d7c487ef34c6b4a1bf
# Successfully built ipadic sacremoses ffmpy
# Installing collected packages: types-python-dateutil, sentencepiece, pydub, ipadic, fuzzywuzzy, ffmpy, bitsandbytes, werkzeug, websockets, typing-extensions, tqdm, shtab, semantic-version, safetensors, rapidfuzz, python-multipart, pynvml, protobuf, Pillow, packaging, orjson, Mako, loguru, joblib, h11, einops, docstring-parser, dill, colorlog, cmaes, aiofiles, xgboost, uvicorn, tiktoken, starlette, scikit-learn, sacremoses, responses, pydantic, multiprocess, jiwer, huggingface-hub, httpcore, arrow, tyro, tokenizers, invisible-watermark, httpx, fastapi, diffusers, codecarbon, alembic, accelerate, transformers, optuna, gradio-client, datasets, trl, peft, gradio, evaluate, autotrain-advanced
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.0.0
#     Uninstalling Werkzeug-3.0.0:
#       Successfully uninstalled Werkzeug-3.0.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.3.2
#     Uninstalling joblib-1.3.2:
#       Successfully uninstalled joblib-1.3.2
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.0.0
#     Uninstalling xgboost-2.0.0:
#       Successfully uninstalled xgboost-2.0.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.13
#     Uninstalling pydantic-1.10.13:
#       Successfully uninstalled pydantic-1.10.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.23.4 which is incompatible.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.
# Successfully installed Mako-1.2.4 Pillow-10.0.0 accelerate-0.24.0 aiofiles-23.2.1 alembic-1.12.0 arrow-1.3.0 autotrain-advanced-0.6.41 bitsandbytes-0.41.1 cmaes-0.10.0 codecarbon-2.2.3 colorlog-6.7.0 datasets-2.14.6 diffusers-0.21.4 dill-0.3.7 docstring-parser-0.15 einops-0.6.1 evaluate-0.3.0 fastapi-0.104.0 ffmpy-0.3.1 fuzzywuzzy-0.18.0 gradio-3.41.0 gradio-client-0.5.0 h11-0.14.0 httpcore-0.18.0 httpx-0.25.0 huggingface-hub-0.17.3 invisible-watermark-0.2.0 ipadic-1.0.0 jiwer-3.0.2 joblib-1.3.1 loguru-0.7.0 multiprocess-0.70.15 optuna-3.3.0 orjson-3.9.9 packaging-23.1 peft-0.5.0 protobuf-4.23.4 pydantic-1.10.11 pydub-0.25.1 pynvml-11.5.0 python-multipart-0.0.6 rapidfuzz-2.13.7 responses-0.18.0 sacremoses-0.0.53 safetensors-0.4.0 scikit-learn-1.3.0 semantic-version-2.10.0 sentencepiece-0.1.99 shtab-1.6.4 starlette-0.27.0 tiktoken-0.5.1 tokenizers-0.14.1 tqdm-4.65.0 transformers-4.34.1 trl-0.7.2 types-python-dateutil-2.8.19.14 typing-extensions-4.8.0 tyro-0.5.10 uvicorn-0.23.2 websockets-11.0.3 werkzeug-2.3.6 xgboost-1.7.6
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.17.3)
# Collecting huggingface_hub
#   Using cached huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.12.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.7.22)
# Installing collected packages: huggingface_hub
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.17.3
#     Uninstalling huggingface-hub-0.17.3:
#       Successfully uninstalled huggingface-hub-0.17.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tokenizers 0.14.1 requires huggingface_hub<0.18,>=0.16.4, but you have huggingface-hub 0.18.0 which is incompatible.
# Successfully installed huggingface_hub-0.18.0

# %% [markdown]
# NB: WARNING restart the runtime.

# %%
# !autotrain setup --update-torch
#!autotrain setup
# Out:
# > INFO    Installing latest transformers@main
# > INFO    Successfully installed latest transformers
# > INFO    Installing latest peft@main
# > INFO    Successfully installed latest peft
# > INFO    Installing latest diffusers@main
# > INFO    Successfully installed latest diffusers
# > INFO    Installing latest trl@main
# > INFO    Successfully installed latest trl
# > INFO    Installing latest xformers
# > INFO    Successfully installed latest xformers
# > INFO    Installing latest PyTorch
# > INFO    Successfully installed latest PyTorch

# %%
# logging to the HF hub to get access to the authentication token
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## AutoTrain training
#
# The code below can just be one line of code, but I have split it in different parts so that you can easily see what is involved.
#
#
#
# ```
# autotrain llm --train --project_name my-llm --model meta-llama/Llama-2-7b-hf --data_path . --use_peft --use_int4 --learning_rate 2e-4 --train_batch_size 12 --num_train_epochs 3 --trainer sft
# ```

# %%
# fine-tune LLM
# !autotrain llm \
--train   \
--project_name 'llama2-MJ-prompts-v3' \
--model 'abhishek/llama-2-7b-hf-small-shards' \
--data_path .  \
--text_column text \
--use_peft  \
--use_int4 \
--fp16  \
--learning_rate 2e-4  \
--train_batch_size 4 \
--num_train_epochs 3 \
#--push_to_hub  \
#--token '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' \
#--repo_id 'llama2-MJ-prompts-v3'  \
--trainer sft  > training.log &\
# Out:
# > INFO    Running LLM
# > INFO    Params: Namespace(version=False, train=True, deploy=False, inference=False, data_path='.', train_split='train', valid_split=None, text_column='text', rejected_text_column='rejected', model='abhishek/llama-2-7b-hf-small-shards', learning_rate=0.0002, num_train_epochs=3, train_batch_size=4, warmup_ratio=0.1, gradient_accumulation_steps=1, optimizer='adamw_torch', scheduler='linear', weight_decay=0.0, max_grad_norm=1.0, seed=42, add_eos_token=False, block_size=-1, use_peft=True, lora_r=16, lora_alpha=32, lora_dropout=0.05, logging_steps=-1, project_name='llama2-MJ-prompts-v3', evaluation_strategy='epoch', save_total_limit=1, save_strategy='epoch', auto_find_batch_size=False, fp16=True, push_to_hub=False, use_int8=False, model_max_length=1024, repo_id=None, use_int4=True, trainer='default', target_modules=None, merge_adapter=False, token=None, backend='default', username=None, use_flash_attention_2=False, log='none', disable_gradient_checkpointing=False, func=<function run_llm_command_factory at 0x7d0fe618f250>)
# > INFO    loading dataset from csv
# Downloading (…)okenizer_config.json: 100% 746/746 [00:00<00:00, 3.44MB/s]
# Downloading tokenizer.model: 100% 500k/500k [00:00<00:00, 554kB/s]
# Downloading (…)/main/tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 7.54MB/s]
# Downloading (…)in/added_tokens.json: 100% 21.0/21.0 [00:00<00:00, 114kB/s]
# Downloading (…)cial_tokens_map.json: 100% 435/435 [00:00<00:00, 2.58MB/s]
# Downloading (…)lve/main/config.json: 100% 625/625 [00:00<00:00, 3.31MB/s]
# Downloading (…)model.bin.index.json: 100% 26.8k/26.8k [00:00<00:00, 86.1MB/s]
# Downloading shards:   0% 0/10 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00010.bin:   0% 0.00/2.95G [00:00<?, ?B/s]
# Downloading (…)l-00001-of-00010.bin:   0% 10.5M/2.95G [00:02<09:35, 5.11MB/s]
# Downloading (…)l-00001-of-00010.bin:   1% 21.0M/2.95G [00:02<05:46, 8.46MB/s]
# Downloading (…)l-00001-of-00010.bin:   1% 31.5M/2.95G [00:03<04:33, 10.7MB/s]
# Downloading (…)l-00001-of-00010.bin:   1% 41.9M/2.95G [00:03<03:35, 13.5MB/s]
# Downloading (…)l-00001-of-00010.bin:   2% 52.4M/2.95G [00:04<03:25, 14.1MB/s]
# Downloading (…)l-00001-of-00010.bin:   2% 62.9M/2.95G [00:05<03:19, 14.5MB/s]
# Downloading (…)l-00001-of-00010.bin:   2% 73.4M/2.95G [00:05<02:55, 16.4MB/s]
# Downloading (…)l-00001-of-00010.bin:   3% 83.9M/2.95G [00:06<02:59, 16.0MB/s]
# Downloading (…)l-00001-of-00010.bin:   3% 94.4M/2.95G [00:07<03:00, 15.9MB/s]
# Downloading (…)l-00001-of-00010.bin:   4% 105M/2.95G [00:07<02:44, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:   4% 115M/2.95G [00:08<02:49, 16.8MB/s]
# Downloading (…)l-00001-of-00010.bin:   4% 126M/2.95G [00:08<02:36, 18.1MB/s]
# Downloading (…)l-00001-of-00010.bin:   5% 136M/2.95G [00:09<02:56, 16.0MB/s]
# Downloading (…)l-00001-of-00010.bin:   5% 147M/2.95G [00:10<02:57, 15.8MB/s]
# Downloading (…)l-00001-of-00010.bin:   5% 157M/2.95G [00:10<02:41, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:   6% 168M/2.95G [00:11<02:46, 16.7MB/s]
# Downloading (…)l-00001-of-00010.bin:   6% 178M/2.95G [00:11<02:34, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:   6% 189M/2.95G [00:12<02:43, 17.0MB/s]
# Downloading (…)l-00001-of-00010.bin:   7% 199M/2.95G [00:13<02:44, 16.8MB/s]
# Downloading (…)l-00001-of-00010.bin:   7% 210M/2.95G [00:13<02:32, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:   7% 220M/2.95G [00:14<02:39, 17.1MB/s]
# Downloading (…)l-00001-of-00010.bin:   8% 231M/2.95G [00:14<02:41, 16.8MB/s]
# Downloading (…)l-00001-of-00010.bin:   8% 241M/2.95G [00:15<02:36, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:   9% 252M/2.95G [00:16<02:38, 17.1MB/s]
# Downloading (…)l-00001-of-00010.bin:   9% 262M/2.95G [00:16<02:42, 16.5MB/s]
# Downloading (…)l-00001-of-00010.bin:   9% 273M/2.95G [00:17<02:44, 16.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  10% 283M/2.95G [00:17<02:30, 17.7MB/s]
# Downloading (…)l-00001-of-00010.bin:  10% 294M/2.95G [00:18<02:37, 16.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  10% 304M/2.95G [00:19<02:41, 16.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  11% 315M/2.95G [00:20<02:43, 16.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  11% 325M/2.95G [00:20<02:29, 17.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  11% 336M/2.95G [00:21<02:34, 16.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  12% 346M/2.95G [00:21<02:38, 16.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  12% 357M/2.95G [00:22<02:25, 17.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  12% 367M/2.95G [00:23<02:44, 15.7MB/s]
# Downloading (…)l-00001-of-00010.bin:  13% 377M/2.95G [00:23<02:39, 16.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  13% 388M/2.95G [00:24<02:30, 17.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  13% 398M/2.95G [00:24<02:29, 17.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  14% 409M/2.95G [00:25<02:22, 17.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  14% 419M/2.95G [00:26<02:28, 17.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  15% 430M/2.95G [00:26<02:28, 17.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  15% 440M/2.95G [00:27<02:21, 17.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  15% 451M/2.95G [00:27<02:22, 17.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  16% 461M/2.95G [00:28<02:27, 16.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  16% 472M/2.95G [00:29<02:16, 18.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  16% 482M/2.95G [00:29<02:22, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  17% 493M/2.95G [00:30<02:17, 17.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  17% 503M/2.95G [00:30<02:17, 17.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  17% 514M/2.95G [00:31<02:13, 18.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  18% 524M/2.95G [00:32<02:14, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  18% 535M/2.95G [00:32<02:20, 17.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  18% 545M/2.95G [00:33<02:15, 17.7MB/s]
# Downloading (…)l-00001-of-00010.bin:  19% 556M/2.95G [00:33<02:15, 17.7MB/s]
# Downloading (…)l-00001-of-00010.bin:  19% 566M/2.95G [00:34<02:11, 18.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  20% 577M/2.95G [00:34<02:11, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  20% 587M/2.95G [00:35<02:09, 18.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  20% 598M/2.95G [00:36<02:18, 17.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  21% 608M/2.95G [00:36<02:20, 16.7MB/s]
# Downloading (…)l-00001-of-00010.bin:  21% 619M/2.95G [00:37<02:22, 16.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  21% 629M/2.95G [00:38<02:10, 17.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  22% 640M/2.95G [00:38<02:15, 17.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  22% 650M/2.95G [00:39<02:18, 16.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  22% 661M/2.95G [00:39<02:07, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  23% 671M/2.95G [00:40<02:14, 16.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  23% 682M/2.95G [00:41<02:03, 18.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  23% 692M/2.95G [00:41<02:10, 17.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  24% 703M/2.95G [00:42<02:14, 16.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  24% 713M/2.95G [00:42<02:09, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  25% 724M/2.95G [00:43<02:07, 17.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  25% 734M/2.95G [00:44<02:05, 17.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  25% 744M/2.95G [00:44<02:08, 17.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  26% 755M/2.95G [00:45<02:06, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  26% 765M/2.95G [00:45<02:03, 17.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  26% 776M/2.95G [00:46<02:02, 17.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  27% 786M/2.95G [00:47<02:00, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  27% 797M/2.95G [00:47<02:05, 17.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  27% 807M/2.95G [00:48<02:03, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  28% 818M/2.95G [00:48<02:00, 17.7MB/s]
# Downloading (…)l-00001-of-00010.bin:  28% 828M/2.95G [00:49<02:00, 17.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  28% 839M/2.95G [00:50<01:56, 18.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  29% 849M/2.95G [00:50<02:01, 17.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  29% 860M/2.95G [00:51<02:00, 17.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  29% 870M/2.95G [00:51<02:02, 17.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  30% 881M/2.95G [00:52<02:05, 16.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  30% 891M/2.95G [00:53<01:56, 17.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  31% 902M/2.95G [00:53<01:59, 17.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  31% 912M/2.95G [00:54<02:02, 16.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  31% 923M/2.95G [00:55<02:08, 15.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  32% 933M/2.95G [00:55<02:03, 16.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  32% 944M/2.95G [00:56<01:58, 17.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  32% 954M/2.95G [00:56<01:55, 17.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  33% 965M/2.95G [00:57<01:59, 16.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  33% 975M/2.95G [00:58<02:01, 16.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  33% 986M/2.95G [00:58<01:53, 17.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  34% 996M/2.95G [00:59<01:56, 16.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  34% 1.01G/2.95G [01:00<01:58, 16.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  34% 1.02G/2.95G [01:00<01:59, 16.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  35% 1.03G/2.95G [01:01<01:49, 17.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  35% 1.04G/2.95G [01:01<01:52, 17.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  36% 1.05G/2.95G [01:02<01:56, 16.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  36% 1.06G/2.95G [01:03<01:46, 17.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  36% 1.07G/2.95G [01:03<01:50, 17.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  37% 1.08G/2.95G [01:04<01:42, 18.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  37% 1.09G/2.95G [01:04<01:47, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  37% 1.10G/2.95G [01:05<01:49, 16.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  38% 1.11G/2.95G [01:06<01:42, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  38% 1.12G/2.95G [01:06<01:45, 17.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  38% 1.13G/2.95G [01:07<01:49, 16.7MB/s]
# Downloading (…)l-00001-of-00010.bin:  39% 1.14G/2.95G [01:07<01:40, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  39% 1.15G/2.95G [01:08<01:44, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  39% 1.16G/2.95G [01:09<01:36, 18.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  40% 1.17G/2.95G [01:09<01:41, 17.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  40% 1.18G/2.95G [01:10<01:55, 15.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  40% 1.20G/2.95G [01:11<01:45, 16.7MB/s]
# Downloading (…)l-00001-of-00010.bin:  41% 1.21G/2.95G [01:11<01:46, 16.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  41% 1.22G/2.95G [01:12<01:47, 16.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  42% 1.23G/2.95G [01:12<01:38, 17.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  42% 1.24G/2.95G [01:13<01:54, 15.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  42% 1.25G/2.95G [01:14<01:52, 15.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  43% 1.26G/2.95G [01:14<01:41, 16.7MB/s]
# Downloading (…)l-00001-of-00010.bin:  43% 1.27G/2.95G [01:15<01:43, 16.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  43% 1.28G/2.95G [01:16<01:44, 16.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  44% 1.29G/2.95G [01:16<01:34, 17.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  44% 1.30G/2.95G [01:17<01:37, 16.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  44% 1.31G/2.95G [01:18<01:40, 16.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  45% 1.32G/2.95G [01:18<01:31, 17.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  45% 1.33G/2.95G [01:19<01:35, 16.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  45% 1.34G/2.95G [01:19<01:37, 16.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  46% 1.35G/2.95G [01:20<01:36, 16.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  46% 1.36G/2.95G [01:21<01:37, 16.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  47% 1.37G/2.95G [01:21<01:33, 16.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  47% 1.38G/2.95G [01:22<01:31, 17.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  47% 1.39G/2.95G [01:23<01:28, 17.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  48% 1.41G/2.95G [01:23<01:31, 16.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  48% 1.42G/2.95G [01:24<01:29, 17.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  48% 1.43G/2.95G [01:24<01:26, 17.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  49% 1.44G/2.95G [01:25<01:25, 17.7MB/s]
# Downloading (…)l-00001-of-00010.bin:  49% 1.45G/2.95G [01:26<01:28, 17.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  49% 1.46G/2.95G [01:26<01:23, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  50% 1.47G/2.95G [01:27<01:26, 17.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  50% 1.48G/2.95G [01:27<01:27, 16.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  50% 1.49G/2.95G [01:28<01:21, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  51% 1.50G/2.95G [01:29<01:23, 17.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  51% 1.51G/2.95G [01:29<01:20, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  51% 1.52G/2.95G [01:30<01:21, 17.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  52% 1.53G/2.95G [01:30<01:23, 17.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  52% 1.54G/2.95G [01:31<01:17, 18.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  53% 1.55G/2.95G [01:32<01:19, 17.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  53% 1.56G/2.95G [01:32<01:15, 18.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  53% 1.57G/2.95G [01:33<01:18, 17.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  54% 1.58G/2.95G [01:33<01:20, 17.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  54% 1.59G/2.95G [01:34<01:14, 18.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  54% 1.60G/2.95G [01:35<01:17, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  55% 1.61G/2.95G [01:35<01:19, 16.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  55% 1.63G/2.95G [01:36<01:13, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  55% 1.64G/2.95G [01:36<01:15, 17.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  56% 1.65G/2.95G [01:37<01:10, 18.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  56% 1.66G/2.95G [01:37<01:13, 17.7MB/s]
# Downloading (…)l-00001-of-00010.bin:  56% 1.67G/2.95G [01:38<01:15, 17.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  57% 1.68G/2.95G [01:39<01:10, 18.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  57% 1.69G/2.95G [01:39<01:13, 17.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  58% 1.70G/2.95G [01:40<01:07, 18.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  58% 1.71G/2.95G [01:40<01:11, 17.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  58% 1.72G/2.95G [01:41<01:12, 17.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  59% 1.73G/2.95G [01:42<01:07, 18.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  59% 1.74G/2.95G [01:42<01:09, 17.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  59% 1.75G/2.95G [01:43<01:11, 16.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  60% 1.76G/2.95G [01:43<01:06, 17.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  60% 1.77G/2.95G [01:44<01:08, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  60% 1.78G/2.95G [01:45<01:04, 18.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  61% 1.79G/2.95G [01:45<01:06, 17.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  61% 1.80G/2.95G [01:46<01:07, 17.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  61% 1.81G/2.95G [01:46<01:03, 17.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  62% 1.82G/2.95G [01:47<01:05, 17.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  62% 1.84G/2.95G [01:48<01:06, 16.7MB/s]
# Downloading (…)l-00001-of-00010.bin:  62% 1.85G/2.95G [01:48<01:01, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  63% 1.86G/2.95G [01:49<01:03, 17.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  63% 1.87G/2.95G [01:49<00:59, 18.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  64% 1.88G/2.95G [01:50<01:01, 17.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  64% 1.89G/2.95G [01:51<00:57, 18.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  64% 1.90G/2.95G [01:51<01:00, 17.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  65% 1.91G/2.95G [01:52<01:01, 16.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  65% 1.92G/2.95G [01:52<00:56, 18.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  65% 1.93G/2.95G [01:53<00:59, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  66% 1.94G/2.95G [01:54<01:00, 16.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  66% 1.95G/2.95G [01:54<00:55, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  66% 1.96G/2.95G [01:55<00:58, 17.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  67% 1.97G/2.95G [01:56<00:59, 16.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  67% 1.98G/2.95G [01:56<00:54, 17.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  67% 1.99G/2.95G [01:57<00:56, 17.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  68% 2.00G/2.95G [01:57<00:57, 16.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  68% 2.01G/2.95G [01:58<00:52, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  69% 2.02G/2.95G [01:58<00:54, 17.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  69% 2.03G/2.95G [01:59<00:50, 18.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  69% 2.04G/2.95G [02:00<00:51, 17.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  70% 2.06G/2.95G [02:00<00:53, 16.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  70% 2.07G/2.95G [02:01<00:49, 17.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  70% 2.08G/2.95G [02:01<00:50, 17.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  71% 2.09G/2.95G [02:02<00:53, 16.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  71% 2.10G/2.95G [02:03<00:51, 16.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  71% 2.11G/2.95G [02:03<00:46, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  72% 2.12G/2.95G [02:04<00:48, 17.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  72% 2.13G/2.95G [02:04<00:44, 18.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  72% 2.14G/2.95G [02:05<00:51, 15.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  73% 2.15G/2.95G [02:06<00:46, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  73% 2.16G/2.95G [02:06<00:47, 16.7MB/s]
# Downloading (…)l-00001-of-00010.bin:  74% 2.17G/2.95G [02:07<00:43, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  74% 2.18G/2.95G [02:08<00:45, 16.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  74% 2.19G/2.95G [02:08<00:46, 16.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  75% 2.20G/2.95G [02:09<00:41, 17.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  75% 2.21G/2.95G [02:09<00:43, 17.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  75% 2.22G/2.95G [02:10<00:44, 16.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  76% 2.23G/2.95G [02:11<00:40, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  76% 2.24G/2.95G [02:11<00:41, 17.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  76% 2.25G/2.95G [02:12<00:42, 16.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  77% 2.26G/2.95G [02:12<00:38, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  77% 2.28G/2.95G [02:13<00:39, 17.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  77% 2.29G/2.95G [02:14<00:40, 16.7MB/s]
# Downloading (…)l-00001-of-00010.bin:  78% 2.30G/2.95G [02:14<00:36, 18.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  78% 2.31G/2.95G [02:15<00:37, 17.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  78% 2.32G/2.95G [02:15<00:34, 18.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  79% 2.33G/2.95G [02:16<00:35, 17.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  79% 2.34G/2.95G [02:17<00:36, 16.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  80% 2.35G/2.95G [02:17<00:33, 18.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  80% 2.36G/2.95G [02:18<00:34, 17.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  80% 2.37G/2.95G [02:19<00:34, 16.7MB/s]
# Downloading (…)l-00001-of-00010.bin:  81% 2.38G/2.95G [02:19<00:31, 18.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  81% 2.39G/2.95G [02:20<00:32, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  81% 2.40G/2.95G [02:20<00:33, 16.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  82% 2.41G/2.95G [02:21<00:32, 16.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  82% 2.42G/2.95G [02:22<00:29, 17.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  82% 2.43G/2.95G [02:22<00:30, 17.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  83% 2.44G/2.95G [02:23<00:30, 16.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  83% 2.45G/2.95G [02:23<00:27, 17.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  83% 2.46G/2.95G [02:24<00:28, 17.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  84% 2.47G/2.95G [02:25<00:28, 16.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  84% 2.49G/2.95G [02:25<00:25, 18.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  85% 2.50G/2.95G [02:26<00:26, 17.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  85% 2.51G/2.95G [02:26<00:24, 18.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  85% 2.52G/2.95G [02:27<00:24, 17.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  86% 2.53G/2.95G [02:28<00:25, 16.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  86% 2.54G/2.95G [02:28<00:25, 16.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  86% 2.55G/2.95G [02:29<00:22, 17.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  87% 2.56G/2.95G [02:29<00:23, 17.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  87% 2.57G/2.95G [02:30<00:21, 18.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  87% 2.58G/2.95G [02:31<00:21, 17.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  88% 2.59G/2.95G [02:31<00:21, 16.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  88% 2.60G/2.95G [02:32<00:19, 18.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  88% 2.61G/2.95G [02:32<00:19, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  89% 2.62G/2.95G [02:33<00:19, 16.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  89% 2.63G/2.95G [02:34<00:17, 18.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  89% 2.64G/2.95G [02:34<00:17, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  90% 2.65G/2.95G [02:35<00:16, 18.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  90% 2.66G/2.95G [02:35<00:16, 17.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  91% 2.67G/2.95G [02:36<00:16, 16.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  91% 2.68G/2.95G [02:37<00:14, 18.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  91% 2.69G/2.95G [02:37<00:14, 17.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  92% 2.71G/2.95G [02:38<00:13, 18.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  92% 2.72G/2.95G [02:38<00:13, 17.6MB/s]
# Downloading (…)l-00001-of-00010.bin:  92% 2.73G/2.95G [02:39<00:14, 15.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  93% 2.74G/2.95G [02:40<00:13, 15.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  93% 2.75G/2.95G [02:40<00:11, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  93% 2.76G/2.95G [02:41<00:11, 16.7MB/s]
# Downloading (…)l-00001-of-00010.bin:  94% 2.77G/2.95G [02:42<00:11, 16.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  94% 2.78G/2.95G [02:42<00:09, 17.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  94% 2.79G/2.95G [02:43<00:09, 17.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  95% 2.80G/2.95G [02:43<00:09, 16.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  95% 2.81G/2.95G [02:44<00:08, 16.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  96% 2.82G/2.95G [02:45<00:08, 16.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  96% 2.83G/2.95G [02:45<00:07, 16.0MB/s]
# Downloading (…)l-00001-of-00010.bin:  96% 2.84G/2.95G [02:46<00:06, 17.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  97% 2.85G/2.95G [02:47<00:05, 16.9MB/s]
# Downloading (…)l-00001-of-00010.bin:  97% 2.86G/2.95G [02:47<00:04, 18.2MB/s]
# Downloading (…)l-00001-of-00010.bin:  97% 2.87G/2.95G [02:48<00:04, 17.3MB/s]
# Downloading (…)l-00001-of-00010.bin:  98% 2.88G/2.95G [02:48<00:04, 16.8MB/s]
# Downloading (…)l-00001-of-00010.bin:  98% 2.89G/2.95G [02:49<00:03, 18.1MB/s]
# Downloading (…)l-00001-of-00010.bin:  98% 2.90G/2.95G [02:50<00:02, 17.4MB/s]
# Downloading (…)l-00001-of-00010.bin:  99% 2.92G/2.95G [02:50<00:02, 18.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  99% 2.93G/2.95G [02:51<00:01, 17.5MB/s]
# Downloading (…)l-00001-of-00010.bin:  99% 2.94G/2.95G [02:51<00:00, 16.9MB/s]
# Downloading (…)l-00001-of-00010.bin: 100% 2.95G/2.95G [02:52<00:00, 18.2MB/s]
# Downloading (…)l-00001-of-00010.bin: 100% 2.95G/2.95G [02:52<00:00, 17.1MB/s]
# Downloading shards:  10% 1/10 [02:54<26:07, 174.22s/it]
# Downloading (…)l-00002-of-00010.bin:   0% 0.00/2.88G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00010.bin:   1% 21.0M/2.88G [00:00<00:25, 111MB/s]
# Downloading (…)l-00002-of-00010.bin:   1% 41.9M/2.88G [00:00<00:22, 126MB/s]
# Downloading (…)l-00002-of-00010.bin:   3% 73.4M/2.88G [00:00<00:15, 183MB/s]
# Downloading (…)l-00002-of-00010.bin:   4% 105M/2.88G [00:00<00:13, 203MB/s]
# Downloading (…)l-00002-of-00010.bin:   5% 136M/2.88G [00:00<00:12, 226MB/s]
# Downloading (…)l-00002-of-00010.bin:   6% 168M/2.88G [00:00<00:12, 221MB/s]
# Downloading (…)l-00002-of-00010.bin:   7% 199M/2.88G [00:01<00:12, 214MB/s]
# Downloading (…)l-00002-of-00010.bin:   8% 231M/2.88G [00:01<00:12, 210MB/s]
# Downloading (…)l-00002-of-00010.bin:   9% 262M/2.88G [00:01<00:12, 214MB/s]
# Downloading (…)l-00002-of-00010.bin:  10% 294M/2.88G [00:01<00:12, 211MB/s]
# Downloading (…)l-00002-of-00010.bin:  11% 325M/2.88G [00:01<00:13, 195MB/s]
# Downloading (…)l-00002-of-00010.bin:  12% 357M/2.88G [00:01<00:13, 194MB/s]
# Downloading (…)l-00002-of-00010.bin:  13% 388M/2.88G [00:01<00:12, 199MB/s]
# Downloading (…)l-00002-of-00010.bin:  15% 419M/2.88G [00:02<00:11, 214MB/s]
# Downloading (…)l-00002-of-00010.bin:  16% 451M/2.88G [00:02<00:12, 202MB/s]
# Downloading (…)l-00002-of-00010.bin:  16% 472M/2.88G [00:02<00:11, 203MB/s]
# Downloading (…)l-00002-of-00010.bin:  17% 493M/2.88G [00:02<00:12, 189MB/s]
# Downloading (…)l-00002-of-00010.bin:  18% 514M/2.88G [00:02<00:14, 167MB/s]
# Downloading (…)l-00002-of-00010.bin:  19% 535M/2.88G [00:02<00:14, 165MB/s]
# Downloading (…)l-00002-of-00010.bin:  19% 556M/2.88G [00:02<00:14, 164MB/s]
# Downloading (…)l-00002-of-00010.bin:  20% 577M/2.88G [00:03<00:15, 151MB/s]
# Downloading (…)l-00002-of-00010.bin:  21% 598M/2.88G [00:03<00:15, 150MB/s]
# Downloading (…)l-00002-of-00010.bin:  22% 619M/2.88G [00:03<00:15, 149MB/s]
# Downloading (…)l-00002-of-00010.bin:  22% 640M/2.88G [00:03<00:14, 154MB/s]
# Downloading (…)l-00002-of-00010.bin:  23% 661M/2.88G [00:03<00:14, 154MB/s]
# Downloading (…)l-00002-of-00010.bin:  24% 682M/2.88G [00:03<00:14, 148MB/s]
# Downloading (…)l-00002-of-00010.bin:  24% 703M/2.88G [00:03<00:14, 150MB/s]
# Downloading (…)l-00002-of-00010.bin:  25% 724M/2.88G [00:04<00:13, 157MB/s]
# Downloading (…)l-00002-of-00010.bin:  26% 755M/2.88G [00:04<00:11, 193MB/s]
# Downloading (…)l-00002-of-00010.bin:  27% 786M/2.88G [00:04<00:10, 202MB/s]
# Downloading (…)l-00002-of-00010.bin:  28% 807M/2.88G [00:04<00:10, 194MB/s]
# Downloading (…)l-00002-of-00010.bin:  29% 839M/2.88G [00:04<00:10, 190MB/s]
# Downloading (…)l-00002-of-00010.bin:  30% 870M/2.88G [00:04<00:10, 200MB/s]
# Downloading (…)l-00002-of-00010.bin:  31% 891M/2.88G [00:04<00:10, 189MB/s]
# Downloading (…)l-00002-of-00010.bin:  32% 923M/2.88G [00:04<00:09, 211MB/s]
# Downloading (…)l-00002-of-00010.bin:  33% 954M/2.88G [00:05<00:08, 229MB/s]
# Downloading (…)l-00002-of-00010.bin:  34% 986M/2.88G [00:05<00:08, 236MB/s]
# Downloading (…)l-00002-of-00010.bin:  35% 1.02G/2.88G [00:05<00:07, 236MB/s]
# Downloading (…)l-00002-of-00010.bin:  36% 1.05G/2.88G [00:05<00:08, 206MB/s]
# Downloading (…)l-00002-of-00010.bin:  38% 1.08G/2.88G [00:05<00:08, 213MB/s]
# Downloading (…)l-00002-of-00010.bin:  39% 1.11G/2.88G [00:05<00:09, 196MB/s]
# Downloading (…)l-00002-of-00010.bin:  39% 1.13G/2.88G [00:05<00:09, 190MB/s]
# Downloading (…)l-00002-of-00010.bin:  40% 1.15G/2.88G [00:06<00:08, 192MB/s]
# Downloading (…)l-00002-of-00010.bin:  41% 1.18G/2.88G [00:06<00:08, 210MB/s]
# Downloading (…)l-00002-of-00010.bin:  42% 1.22G/2.88G [00:06<00:07, 215MB/s]
# Downloading (…)l-00002-of-00010.bin:  43% 1.25G/2.88G [00:06<00:07, 222MB/s]
# Downloading (…)l-00002-of-00010.bin:  44% 1.28G/2.88G [00:06<00:06, 230MB/s]
# Downloading (…)l-00002-of-00010.bin:  46% 1.31G/2.88G [00:06<00:06, 237MB/s]
# Downloading (…)l-00002-of-00010.bin:  47% 1.34G/2.88G [00:06<00:06, 232MB/s]
# Downloading (…)l-00002-of-00010.bin:  48% 1.37G/2.88G [00:07<00:06, 225MB/s]
# Downloading (…)l-00002-of-00010.bin:  49% 1.41G/2.88G [00:07<00:06, 214MB/s]
# Downloading (…)l-00002-of-00010.bin:  50% 1.44G/2.88G [00:07<00:06, 224MB/s]
# Downloading (…)l-00002-of-00010.bin:  51% 1.47G/2.88G [00:07<00:06, 226MB/s]
# Downloading (…)l-00002-of-00010.bin:  52% 1.50G/2.88G [00:07<00:05, 239MB/s]
# Downloading (…)l-00002-of-00010.bin:  53% 1.53G/2.88G [00:07<00:05, 240MB/s]
# Downloading (…)l-00002-of-00010.bin:  54% 1.56G/2.88G [00:07<00:06, 214MB/s]
# Downloading (…)l-00002-of-00010.bin:  55% 1.59G/2.88G [00:08<00:05, 221MB/s]
# Downloading (…)l-00002-of-00010.bin:  56% 1.63G/2.88G [00:08<00:05, 215MB/s]
# Downloading (…)l-00002-of-00010.bin:  58% 1.66G/2.88G [00:08<00:05, 213MB/s]
# Downloading (…)l-00002-of-00010.bin:  59% 1.69G/2.88G [00:08<00:05, 221MB/s]
# Downloading (…)l-00002-of-00010.bin:  60% 1.72G/2.88G [00:08<00:05, 220MB/s]
# Downloading (…)l-00002-of-00010.bin:  61% 1.75G/2.88G [00:08<00:04, 241MB/s]
# Downloading (…)l-00002-of-00010.bin:  62% 1.78G/2.88G [00:08<00:04, 231MB/s]
# Downloading (…)l-00002-of-00010.bin:  63% 1.81G/2.88G [00:08<00:04, 232MB/s]
# Downloading (…)l-00002-of-00010.bin:  64% 1.85G/2.88G [00:09<00:04, 244MB/s]
# Downloading (…)l-00002-of-00010.bin:  65% 1.88G/2.88G [00:09<00:04, 236MB/s]
# Downloading (…)l-00002-of-00010.bin:  66% 1.91G/2.88G [00:09<00:03, 243MB/s]
# Downloading (…)l-00002-of-00010.bin:  67% 1.94G/2.88G [00:09<00:03, 236MB/s]
# Downloading (…)l-00002-of-00010.bin:  69% 1.97G/2.88G [00:09<00:03, 233MB/s]
# Downloading (…)l-00002-of-00010.bin:  70% 2.01G/2.88G [00:09<00:03, 265MB/s]
# Downloading (…)l-00002-of-00010.bin:  71% 2.06G/2.88G [00:09<00:02, 275MB/s]
# Downloading (…)l-00002-of-00010.bin:  73% 2.09G/2.88G [00:10<00:03, 201MB/s]
# Downloading (…)l-00002-of-00010.bin:  74% 2.12G/2.88G [00:10<00:05, 145MB/s]
# Downloading (…)l-00002-of-00010.bin:  74% 2.14G/2.88G [00:10<00:05, 130MB/s]
# Downloading (…)l-00002-of-00010.bin:  75% 2.16G/2.88G [00:11<00:06, 116MB/s]
# Downloading (…)l-00002-of-00010.bin:  76% 2.18G/2.88G [00:11<00:06, 107MB/s]
# Downloading (…)l-00002-of-00010.bin:  77% 2.20G/2.88G [00:11<00:06, 96.9MB/s]
# Downloading (…)l-00002-of-00010.bin:  77% 2.22G/2.88G [00:11<00:07, 84.7MB/s]
# Downloading (…)l-00002-of-00010.bin:  78% 2.23G/2.88G [00:11<00:07, 85.2MB/s]
# Downloading (…)l-00002-of-00010.bin:  78% 2.25G/2.88G [00:12<00:06, 89.6MB/s]
# Downloading (…)l-00002-of-00010.bin:  79% 2.28G/2.88G [00:12<00:06, 97.5MB/s]
# Downloading (…)l-00002-of-00010.bin:  80% 2.30G/2.88G [00:12<00:05, 108MB/s]
# Downloading (…)l-00002-of-00010.bin:  81% 2.33G/2.88G [00:12<00:03, 141MB/s]
# Downloading (…)l-00002-of-00010.bin:  82% 2.35G/2.88G [00:12<00:03, 155MB/s]
# Downloading (…)l-00002-of-00010.bin:  83% 2.38G/2.88G [00:12<00:02, 176MB/s]
# Downloading (…)l-00002-of-00010.bin:  83% 2.40G/2.88G [00:12<00:02, 176MB/s]
# Downloading (…)l-00002-of-00010.bin:  85% 2.43G/2.88G [00:13<00:02, 188MB/s]
# Downloading (…)l-00002-of-00010.bin:  85% 2.45G/2.88G [00:13<00:02, 155MB/s]
# Downloading (…)l-00002-of-00010.bin:  86% 2.49G/2.88G [00:13<00:02, 183MB/s]
# Downloading (…)l-00002-of-00010.bin:  87% 2.52G/2.88G [00:13<00:01, 212MB/s]
# Downloading (…)l-00002-of-00010.bin:  89% 2.55G/2.88G [00:13<00:01, 236MB/s]
# Downloading (…)l-00002-of-00010.bin:  90% 2.58G/2.88G [00:13<00:01, 222MB/s]
# Downloading (…)l-00002-of-00010.bin:  91% 2.61G/2.88G [00:13<00:01, 208MB/s]
# Downloading (…)l-00002-of-00010.bin:  92% 2.64G/2.88G [00:14<00:01, 208MB/s]
# Downloading (…)l-00002-of-00010.bin:  93% 2.67G/2.88G [00:14<00:00, 216MB/s]
# Downloading (…)l-00002-of-00010.bin:  94% 2.71G/2.88G [00:14<00:00, 218MB/s]
# Downloading (…)l-00002-of-00010.bin:  95% 2.74G/2.88G [00:14<00:00, 228MB/s]
# Downloading (…)l-00002-of-00010.bin:  96% 2.77G/2.88G [00:14<00:00, 209MB/s]
# Downloading (…)l-00002-of-00010.bin:  97% 2.80G/2.88G [00:14<00:00, 220MB/s]
# Downloading (…)l-00002-of-00010.bin:  98% 2.83G/2.88G [00:14<00:00, 224MB/s]
# Downloading (…)l-00002-of-00010.bin: 100% 2.88G/2.88G [00:15<00:00, 190MB/s]
# Downloading shards:  20% 2/10 [03:09<10:46, 80.81s/it]
# Downloading (…)l-00003-of-00010.bin:   0% 0.00/2.99G [00:00<?, ?B/s]
# Downloading (…)l-00003-of-00010.bin:   0% 10.5M/2.99G [00:02<09:41, 5.13MB/s]
# Downloading (…)l-00003-of-00010.bin:   1% 21.0M/2.99G [00:02<05:52, 8.43MB/s]
# Downloading (…)l-00003-of-00010.bin:   1% 31.5M/2.99G [00:03<04:37, 10.7MB/s]
# Downloading (…)l-00003-of-00010.bin:   1% 41.9M/2.99G [00:03<03:39, 13.4MB/s]
# Downloading (…)l-00003-of-00010.bin:   2% 52.4M/2.99G [00:04<03:27, 14.1MB/s]
# Downloading (…)l-00003-of-00010.bin:   2% 62.9M/2.99G [00:05<03:21, 14.5MB/s]
# Downloading (…)l-00003-of-00010.bin:   2% 73.4M/2.99G [00:05<02:57, 16.4MB/s]
# Downloading (…)l-00003-of-00010.bin:   3% 83.9M/2.99G [00:06<03:00, 16.1MB/s]
# Downloading (…)l-00003-of-00010.bin:   3% 94.4M/2.99G [00:07<03:02, 15.9MB/s]
# Downloading (…)l-00003-of-00010.bin:   4% 105M/2.99G [00:07<02:45, 17.4MB/s]
# Downloading (…)l-00003-of-00010.bin:   4% 115M/2.99G [00:08<02:51, 16.8MB/s]
# Downloading (…)l-00003-of-00010.bin:   4% 126M/2.99G [00:08<02:55, 16.3MB/s]
# Downloading (…)l-00003-of-00010.bin:   5% 136M/2.99G [00:09<02:40, 17.7MB/s]
# Downloading (…)l-00003-of-00010.bin:   5% 147M/2.99G [00:10<02:46, 17.1MB/s]
# Downloading (…)l-00003-of-00010.bin:   5% 157M/2.99G [00:10<02:51, 16.5MB/s]
# Downloading (…)l-00003-of-00010.bin:   6% 168M/2.99G [00:11<02:37, 18.0MB/s]
# Downloading (…)l-00003-of-00010.bin:   6% 178M/2.99G [00:11<02:43, 17.2MB/s]
# Downloading (…)l-00003-of-00010.bin:   6% 189M/2.99G [00:12<02:49, 16.6MB/s]
# Downloading (…)l-00003-of-00010.bin:   7% 199M/2.99G [00:13<02:35, 18.0MB/s]
# Downloading (…)l-00003-of-00010.bin:   7% 210M/2.99G [00:13<02:42, 17.1MB/s]
# Downloading (…)l-00003-of-00010.bin:   7% 220M/2.99G [00:14<02:30, 18.4MB/s]
# Downloading (…)l-00003-of-00010.bin:   8% 231M/2.99G [00:14<02:38, 17.4MB/s]
# Downloading (…)l-00003-of-00010.bin:   8% 241M/2.99G [00:15<02:44, 16.8MB/s]
# Downloading (…)l-00003-of-00010.bin:   8% 252M/2.99G [00:15<02:30, 18.2MB/s]
# Downloading (…)l-00003-of-00010.bin:   9% 262M/2.99G [00:16<02:38, 17.2MB/s]
# Downloading (…)l-00003-of-00010.bin:   9% 273M/2.99G [00:17<02:43, 16.7MB/s]
# Downloading (…)l-00003-of-00010.bin:   9% 283M/2.99G [00:17<02:30, 18.0MB/s]
# Downloading (…)l-00003-of-00010.bin:  10% 294M/2.99G [00:18<02:37, 17.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  10% 304M/2.99G [00:19<02:42, 16.6MB/s]
# Downloading (…)l-00003-of-00010.bin:  11% 315M/2.99G [00:19<02:28, 18.0MB/s]
# Downloading (…)l-00003-of-00010.bin:  11% 325M/2.99G [00:20<02:35, 17.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  11% 336M/2.99G [00:20<02:23, 18.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  12% 346M/2.99G [00:21<02:31, 17.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  12% 357M/2.99G [00:22<02:36, 16.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  12% 367M/2.99G [00:22<02:25, 18.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  13% 377M/2.99G [00:23<02:30, 17.3MB/s]
# Downloading (…)l-00003-of-00010.bin:  13% 388M/2.99G [00:23<02:35, 16.7MB/s]
# Downloading (…)l-00003-of-00010.bin:  13% 398M/2.99G [00:24<02:24, 17.9MB/s]
# Downloading (…)l-00003-of-00010.bin:  14% 409M/2.99G [00:25<02:30, 17.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  14% 419M/2.99G [00:25<02:21, 18.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  14% 430M/2.99G [00:26<02:26, 17.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  15% 440M/2.99G [00:26<02:32, 16.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  15% 451M/2.99G [00:27<02:34, 16.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  15% 461M/2.99G [00:28<02:21, 17.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  16% 472M/2.99G [00:28<02:27, 17.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  16% 482M/2.99G [00:29<02:17, 18.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  16% 493M/2.99G [00:30<02:39, 15.7MB/s]
# Downloading (…)l-00003-of-00010.bin:  17% 503M/2.99G [00:30<02:25, 17.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  17% 514M/2.99G [00:31<02:28, 16.7MB/s]
# Downloading (…)l-00003-of-00010.bin:  18% 524M/2.99G [00:31<02:31, 16.3MB/s]
# Downloading (…)l-00003-of-00010.bin:  18% 535M/2.99G [00:32<02:18, 17.7MB/s]
# Downloading (…)l-00003-of-00010.bin:  18% 545M/2.99G [00:33<02:24, 16.9MB/s]
# Downloading (…)l-00003-of-00010.bin:  19% 556M/2.99G [00:33<02:28, 16.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  19% 566M/2.99G [00:34<02:30, 16.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  19% 577M/2.99G [00:34<02:17, 17.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  20% 587M/2.99G [00:35<02:22, 16.9MB/s]
# Downloading (…)l-00003-of-00010.bin:  20% 598M/2.99G [00:36<02:27, 16.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  20% 608M/2.99G [00:37<02:27, 16.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  21% 619M/2.99G [00:37<02:15, 17.6MB/s]
# Downloading (…)l-00003-of-00010.bin:  21% 629M/2.99G [00:38<02:19, 16.9MB/s]
# Downloading (…)l-00003-of-00010.bin:  21% 640M/2.99G [00:38<02:23, 16.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  22% 650M/2.99G [00:39<02:11, 17.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  22% 661M/2.99G [00:39<02:17, 16.9MB/s]
# Downloading (…)l-00003-of-00010.bin:  22% 671M/2.99G [00:40<02:20, 16.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  23% 682M/2.99G [00:41<02:09, 17.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  23% 692M/2.99G [00:41<02:14, 17.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  23% 703M/2.99G [00:42<02:05, 18.3MB/s]
# Downloading (…)l-00003-of-00010.bin:  24% 713M/2.99G [00:42<02:11, 17.3MB/s]
# Downloading (…)l-00003-of-00010.bin:  24% 724M/2.99G [00:43<02:15, 16.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  25% 734M/2.99G [00:44<02:17, 16.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  25% 744M/2.99G [00:44<02:06, 17.7MB/s]
# Downloading (…)l-00003-of-00010.bin:  25% 755M/2.99G [00:45<02:10, 17.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  26% 765M/2.99G [00:45<02:01, 18.3MB/s]
# Downloading (…)l-00003-of-00010.bin:  26% 776M/2.99G [00:46<02:06, 17.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  26% 786M/2.99G [00:47<01:58, 18.6MB/s]
# Downloading (…)l-00003-of-00010.bin:  27% 797M/2.99G [00:47<02:05, 17.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  27% 807M/2.99G [00:48<02:08, 17.0MB/s]
# Downloading (…)l-00003-of-00010.bin:  27% 818M/2.99G [00:48<02:00, 18.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  28% 828M/2.99G [00:49<02:06, 17.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  28% 839M/2.99G [00:50<02:07, 16.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  28% 849M/2.99G [00:50<01:58, 18.0MB/s]
# Downloading (…)l-00003-of-00010.bin:  29% 860M/2.99G [00:51<02:02, 17.3MB/s]
# Downloading (…)l-00003-of-00010.bin:  29% 870M/2.99G [00:51<01:54, 18.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  29% 881M/2.99G [00:52<01:59, 17.6MB/s]
# Downloading (…)l-00003-of-00010.bin:  30% 891M/2.99G [00:53<02:05, 16.7MB/s]
# Downloading (…)l-00003-of-00010.bin:  30% 902M/2.99G [00:53<02:07, 16.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  31% 912M/2.99G [00:54<01:57, 17.6MB/s]
# Downloading (…)l-00003-of-00010.bin:  31% 923M/2.99G [00:55<02:01, 17.0MB/s]
# Downloading (…)l-00003-of-00010.bin:  31% 933M/2.99G [00:55<02:04, 16.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  32% 944M/2.99G [00:56<01:54, 17.9MB/s]
# Downloading (…)l-00003-of-00010.bin:  32% 954M/2.99G [00:56<01:58, 17.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  32% 965M/2.99G [00:57<01:49, 18.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  33% 975M/2.99G [00:58<01:56, 17.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  33% 986M/2.99G [00:58<01:48, 18.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  33% 996M/2.99G [00:59<01:53, 17.6MB/s]
# Downloading (…)l-00003-of-00010.bin:  34% 1.01G/2.99G [00:59<01:57, 16.9MB/s]
# Downloading (…)l-00003-of-00010.bin:  34% 1.02G/2.99G [01:00<02:00, 16.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  34% 1.03G/2.99G [01:01<01:49, 17.9MB/s]
# Downloading (…)l-00003-of-00010.bin:  35% 1.04G/2.99G [01:01<01:54, 17.0MB/s]
# Downloading (…)l-00003-of-00010.bin:  35% 1.05G/2.99G [01:02<01:58, 16.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  35% 1.06G/2.99G [01:02<01:47, 17.9MB/s]
# Downloading (…)l-00003-of-00010.bin:  36% 1.07G/2.99G [01:03<01:52, 17.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  36% 1.08G/2.99G [01:04<01:55, 16.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  36% 1.09G/2.99G [01:04<01:46, 17.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  37% 1.10G/2.99G [01:05<01:50, 17.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  37% 1.11G/2.99G [01:06<01:54, 16.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  38% 1.12G/2.99G [01:06<01:43, 18.0MB/s]
# Downloading (…)l-00003-of-00010.bin:  38% 1.13G/2.99G [01:07<01:48, 17.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  38% 1.14G/2.99G [01:07<01:40, 18.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  39% 1.15G/2.99G [01:08<01:45, 17.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  39% 1.16G/2.99G [01:09<01:48, 16.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  39% 1.17G/2.99G [01:09<01:39, 18.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  40% 1.18G/2.99G [01:10<01:45, 17.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  40% 1.20G/2.99G [01:10<01:37, 18.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  40% 1.21G/2.99G [01:11<01:42, 17.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  41% 1.22G/2.99G [01:12<01:46, 16.7MB/s]
# Downloading (…)l-00003-of-00010.bin:  41% 1.23G/2.99G [01:12<01:48, 16.3MB/s]
# Downloading (…)l-00003-of-00010.bin:  41% 1.24G/2.99G [01:13<01:38, 17.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  42% 1.25G/2.99G [01:13<01:43, 16.9MB/s]
# Downloading (…)l-00003-of-00010.bin:  42% 1.26G/2.99G [01:14<01:45, 16.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  42% 1.27G/2.99G [01:15<01:36, 17.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  43% 1.28G/2.99G [01:15<01:40, 17.0MB/s]
# Downloading (…)l-00003-of-00010.bin:  43% 1.29G/2.99G [01:16<01:42, 16.6MB/s]
# Downloading (…)l-00003-of-00010.bin:  43% 1.30G/2.99G [01:16<01:34, 17.9MB/s]
# Downloading (…)l-00003-of-00010.bin:  44% 1.31G/2.99G [01:17<01:37, 17.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  44% 1.32G/2.99G [01:17<01:31, 18.3MB/s]
# Downloading (…)l-00003-of-00010.bin:  45% 1.33G/2.99G [01:18<01:35, 17.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  45% 1.34G/2.99G [01:19<01:38, 16.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  45% 1.35G/2.99G [01:19<01:30, 18.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  46% 1.36G/2.99G [01:20<01:34, 17.3MB/s]
# Downloading (…)l-00003-of-00010.bin:  46% 1.37G/2.99G [01:20<01:27, 18.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  46% 1.38G/2.99G [01:21<01:32, 17.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  47% 1.39G/2.99G [01:22<01:34, 16.9MB/s]
# Downloading (…)l-00003-of-00010.bin:  47% 1.41G/2.99G [01:22<01:27, 18.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  47% 1.42G/2.99G [01:23<01:30, 17.3MB/s]
# Downloading (…)l-00003-of-00010.bin:  48% 1.43G/2.99G [01:24<01:33, 16.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  48% 1.44G/2.99G [01:24<01:26, 18.0MB/s]
# Downloading (…)l-00003-of-00010.bin:  48% 1.45G/2.99G [01:25<01:29, 17.3MB/s]
# Downloading (…)l-00003-of-00010.bin:  49% 1.46G/2.99G [01:25<01:23, 18.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  49% 1.47G/2.99G [01:26<01:26, 17.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  49% 1.48G/2.99G [01:27<01:29, 16.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  50% 1.49G/2.99G [01:27<01:31, 16.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  50% 1.50G/2.99G [01:28<01:23, 17.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  50% 1.51G/2.99G [01:28<01:27, 17.0MB/s]
# Downloading (…)l-00003-of-00010.bin:  51% 1.52G/2.99G [01:29<01:29, 16.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  51% 1.53G/2.99G [01:30<01:21, 17.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  52% 1.54G/2.99G [01:30<01:24, 17.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  52% 1.55G/2.99G [01:31<01:26, 16.6MB/s]
# Downloading (…)l-00003-of-00010.bin:  52% 1.56G/2.99G [01:32<01:28, 16.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  53% 1.57G/2.99G [01:32<01:20, 17.6MB/s]
# Downloading (…)l-00003-of-00010.bin:  53% 1.58G/2.99G [01:33<01:23, 16.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  53% 1.59G/2.99G [01:33<01:24, 16.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  54% 1.60G/2.99G [01:34<01:17, 17.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  54% 1.61G/2.99G [01:35<01:20, 17.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  54% 1.63G/2.99G [01:35<01:22, 16.6MB/s]
# Downloading (…)l-00003-of-00010.bin:  55% 1.64G/2.99G [01:36<01:15, 18.0MB/s]
# Downloading (…)l-00003-of-00010.bin:  55% 1.65G/2.99G [01:36<01:18, 17.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  55% 1.66G/2.99G [01:37<01:12, 18.3MB/s]
# Downloading (…)l-00003-of-00010.bin:  56% 1.67G/2.99G [01:38<01:15, 17.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  56% 1.68G/2.99G [01:38<01:17, 16.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  56% 1.69G/2.99G [01:39<01:11, 18.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  57% 1.70G/2.99G [01:39<01:14, 17.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  57% 1.71G/2.99G [01:40<01:16, 16.7MB/s]
# Downloading (…)l-00003-of-00010.bin:  58% 1.72G/2.99G [01:41<01:12, 17.6MB/s]
# Downloading (…)l-00003-of-00010.bin:  58% 1.73G/2.99G [01:41<01:12, 17.3MB/s]
# Downloading (…)l-00003-of-00010.bin:  58% 1.74G/2.99G [01:42<01:08, 18.3MB/s]
# Downloading (…)l-00003-of-00010.bin:  59% 1.75G/2.99G [01:42<01:10, 17.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  59% 1.76G/2.99G [01:43<01:12, 16.9MB/s]
# Downloading (…)l-00003-of-00010.bin:  59% 1.77G/2.99G [01:44<01:06, 18.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  60% 1.78G/2.99G [01:44<01:09, 17.3MB/s]
# Downloading (…)l-00003-of-00010.bin:  60% 1.79G/2.99G [01:45<01:11, 16.7MB/s]
# Downloading (…)l-00003-of-00010.bin:  60% 1.80G/2.99G [01:45<01:05, 18.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  61% 1.81G/2.99G [01:46<01:08, 17.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  61% 1.82G/2.99G [01:46<01:03, 18.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  61% 1.84G/2.99G [01:47<01:06, 17.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  62% 1.85G/2.99G [01:48<01:07, 16.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  62% 1.86G/2.99G [01:48<01:02, 18.0MB/s]
# Downloading (…)l-00003-of-00010.bin:  62% 1.87G/2.99G [01:49<01:05, 17.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  63% 1.88G/2.99G [01:50<01:06, 16.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  63% 1.89G/2.99G [01:50<01:01, 18.0MB/s]
# Downloading (…)l-00003-of-00010.bin:  63% 1.90G/2.99G [01:51<01:03, 17.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  64% 1.91G/2.99G [01:51<00:58, 18.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  64% 1.92G/2.99G [01:52<01:01, 17.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  65% 1.93G/2.99G [01:53<01:03, 16.7MB/s]
# Downloading (…)l-00003-of-00010.bin:  65% 1.94G/2.99G [01:53<00:57, 18.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  65% 1.95G/2.99G [01:54<01:00, 17.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  66% 1.96G/2.99G [01:54<00:55, 18.5MB/s]
# Downloading (…)l-00003-of-00010.bin:  66% 1.97G/2.99G [01:55<00:58, 17.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  66% 1.98G/2.99G [01:56<00:59, 16.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  67% 1.99G/2.99G [01:56<01:01, 16.3MB/s]
# Downloading (…)l-00003-of-00010.bin:  67% 2.00G/2.99G [01:57<00:55, 17.7MB/s]
# Downloading (…)l-00003-of-00010.bin:  67% 2.01G/2.99G [01:57<00:57, 17.0MB/s]
# Downloading (…)l-00003-of-00010.bin:  68% 2.02G/2.99G [01:58<00:53, 18.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  68% 2.03G/2.99G [01:59<00:54, 17.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  68% 2.04G/2.99G [01:59<00:56, 16.8MB/s]
# Downloading (…)l-00003-of-00010.bin:  69% 2.06G/2.99G [02:00<00:51, 18.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  69% 2.07G/2.99G [02:00<00:53, 17.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  69% 2.08G/2.99G [02:01<00:54, 16.7MB/s]
# Downloading (…)l-00003-of-00010.bin:  70% 2.09G/2.99G [02:02<00:50, 17.9MB/s]
# Downloading (…)l-00003-of-00010.bin:  70% 2.10G/2.99G [02:02<00:52, 17.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  70% 2.11G/2.99G [02:03<00:53, 16.6MB/s]
# Downloading (…)l-00003-of-00010.bin:  71% 2.12G/2.99G [02:03<00:48, 18.0MB/s]
# Downloading (…)l-00003-of-00010.bin:  71% 2.13G/2.99G [02:04<00:50, 17.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  72% 2.14G/2.99G [02:05<00:46, 18.3MB/s]
# Downloading (…)l-00003-of-00010.bin:  72% 2.15G/2.99G [02:05<00:48, 17.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  72% 2.16G/2.99G [02:06<00:49, 16.7MB/s]
# Downloading (…)l-00003-of-00010.bin:  73% 2.17G/2.99G [02:06<00:45, 18.1MB/s]
# Downloading (…)l-00003-of-00010.bin:  73% 2.18G/2.99G [02:07<00:46, 17.2MB/s]
# Downloading (…)l-00003-of-00010.bin:  73% 2.19G/2.99G [02:08<00:43, 18.4MB/s]
# Downloading (…)l-00003-of-00010.bin:  74% 2.20G/2.99G [02:08<00:45, 17.5MB/s]
# ...
# Downloading (…)l-00009-of-00010.bin:  68% 1.93G/2.86G [01:51<00:53, 17.4MB/s]
# Downloading (…)l-00009-of-00010.bin:  68% 1.94G/2.86G [01:52<00:54, 16.8MB/s]
# Downloading (…)l-00009-of-00010.bin:  68% 1.95G/2.86G [01:52<00:50, 17.9MB/s]
# Downloading (…)l-00009-of-00010.bin:  69% 1.96G/2.86G [01:53<00:51, 17.3MB/s]
# Downloading (…)l-00009-of-00010.bin:  69% 1.97G/2.86G [01:53<00:48, 18.4MB/s]
# Downloading (…)l-00009-of-00010.bin:  69% 1.98G/2.86G [01:54<00:49, 17.6MB/s]
# Downloading (…)l-00009-of-00010.bin:  70% 1.99G/2.86G [01:54<00:51, 16.9MB/s]
# Downloading (…)l-00009-of-00010.bin:  70% 2.00G/2.86G [01:55<00:47, 18.0MB/s]
# Downloading (…)l-00009-of-00010.bin:  70% 2.01G/2.86G [01:56<00:48, 17.4MB/s]
# Downloading (…)l-00009-of-00010.bin:  71% 2.02G/2.86G [01:56<00:45, 18.4MB/s]
# Downloading (…)l-00009-of-00010.bin:  71% 2.03G/2.86G [01:57<00:46, 17.6MB/s]
# Downloading (…)l-00009-of-00010.bin:  72% 2.04G/2.86G [01:57<00:48, 16.9MB/s]
# Downloading (…)l-00009-of-00010.bin:  72% 2.06G/2.86G [01:58<00:44, 18.1MB/s]
# Downloading (…)l-00009-of-00010.bin:  72% 2.07G/2.86G [01:59<00:46, 17.0MB/s]
# Downloading (…)l-00009-of-00010.bin:  73% 2.08G/2.86G [01:59<00:46, 16.8MB/s]
# Downloading (…)l-00009-of-00010.bin:  73% 2.09G/2.86G [02:00<00:43, 17.8MB/s]
# Downloading (…)l-00009-of-00010.bin:  73% 2.10G/2.86G [02:01<00:46, 16.5MB/s]
# Downloading (…)l-00009-of-00010.bin:  74% 2.11G/2.86G [02:01<00:46, 16.0MB/s]
# Downloading (…)l-00009-of-00010.bin:  74% 2.12G/2.86G [02:02<00:46, 15.9MB/s]
# Downloading (…)l-00009-of-00010.bin:  75% 2.13G/2.86G [02:02<00:41, 17.4MB/s]
# Downloading (…)l-00009-of-00010.bin:  75% 2.14G/2.86G [02:03<00:42, 16.7MB/s]
# Downloading (…)l-00009-of-00010.bin:  75% 2.15G/2.86G [02:04<00:39, 18.1MB/s]
# Downloading (…)l-00009-of-00010.bin:  76% 2.16G/2.86G [02:04<00:40, 17.3MB/s]
# Downloading (…)l-00009-of-00010.bin:  76% 2.17G/2.86G [02:05<00:40, 16.8MB/s]
# Downloading (…)l-00009-of-00010.bin:  76% 2.18G/2.86G [02:05<00:37, 18.0MB/s]
# Downloading (…)l-00009-of-00010.bin:  77% 2.19G/2.86G [02:06<00:38, 17.2MB/s]
# Downloading (…)l-00009-of-00010.bin:  77% 2.20G/2.86G [02:07<00:39, 16.7MB/s]
# Downloading (…)l-00009-of-00010.bin:  77% 2.21G/2.86G [02:07<00:35, 18.1MB/s]
# Downloading (…)l-00009-of-00010.bin:  78% 2.22G/2.86G [02:08<00:36, 17.1MB/s]
# Downloading (…)l-00009-of-00010.bin:  78% 2.23G/2.86G [02:08<00:34, 18.2MB/s]
# Downloading (…)l-00009-of-00010.bin:  79% 2.24G/2.86G [02:09<00:34, 17.5MB/s]
# Downloading (…)l-00009-of-00010.bin:  79% 2.25G/2.86G [02:10<00:35, 16.8MB/s]
# Downloading (…)l-00009-of-00010.bin:  79% 2.26G/2.86G [02:10<00:32, 18.0MB/s]
# Downloading (…)l-00009-of-00010.bin:  80% 2.28G/2.86G [02:11<00:33, 17.3MB/s]
# Downloading (…)l-00009-of-00010.bin:  80% 2.29G/2.86G [02:11<00:34, 16.7MB/s]
# Downloading (…)l-00009-of-00010.bin:  80% 2.30G/2.86G [02:12<00:31, 17.9MB/s]
# Downloading (…)l-00009-of-00010.bin:  81% 2.31G/2.86G [02:13<00:32, 17.1MB/s]
# Downloading (…)l-00009-of-00010.bin:  81% 2.32G/2.86G [02:13<00:33, 15.9MB/s]
# Downloading (…)l-00009-of-00010.bin:  81% 2.33G/2.86G [02:14<00:32, 16.1MB/s]
# Downloading (…)l-00009-of-00010.bin:  82% 2.34G/2.86G [02:15<00:29, 17.4MB/s]
# Downloading (…)l-00009-of-00010.bin:  82% 2.35G/2.86G [02:15<00:30, 16.9MB/s]
# Downloading (…)l-00009-of-00010.bin:  83% 2.36G/2.86G [02:16<00:29, 16.6MB/s]
# Downloading (…)l-00009-of-00010.bin:  83% 2.37G/2.86G [02:16<00:27, 17.7MB/s]
# Downloading (…)l-00009-of-00010.bin:  83% 2.38G/2.86G [02:17<00:27, 17.4MB/s]
# Downloading (…)l-00009-of-00010.bin:  84% 2.39G/2.86G [02:18<00:25, 18.1MB/s]
# Downloading (…)l-00009-of-00010.bin:  84% 2.40G/2.86G [02:18<00:26, 16.9MB/s]
# Downloading (…)l-00009-of-00010.bin:  84% 2.41G/2.86G [02:19<00:25, 17.2MB/s]
# Downloading (…)l-00009-of-00010.bin:  85% 2.42G/2.86G [02:19<00:23, 18.3MB/s]
# Downloading (…)l-00009-of-00010.bin:  85% 2.43G/2.86G [02:20<00:24, 17.5MB/s]
# Downloading (…)l-00009-of-00010.bin:  86% 2.44G/2.86G [02:21<00:24, 16.8MB/s]
# Downloading (…)l-00009-of-00010.bin:  86% 2.45G/2.86G [02:21<00:22, 17.8MB/s]
# Downloading (…)l-00009-of-00010.bin:  86% 2.46G/2.86G [02:22<00:23, 16.7MB/s]
# Downloading (…)l-00009-of-00010.bin:  87% 2.47G/2.86G [02:23<00:22, 16.6MB/s]
# Downloading (…)l-00009-of-00010.bin:  87% 2.49G/2.86G [02:23<00:20, 17.7MB/s]
# Downloading (…)l-00009-of-00010.bin:  87% 2.50G/2.86G [02:24<00:21, 17.1MB/s]
# Downloading (…)l-00009-of-00010.bin:  88% 2.51G/2.86G [02:24<00:20, 17.1MB/s]
# Downloading (…)l-00009-of-00010.bin:  88% 2.52G/2.86G [02:25<00:21, 15.7MB/s]
# Downloading (…)l-00009-of-00010.bin:  88% 2.53G/2.86G [02:25<00:18, 17.8MB/s]
# Downloading (…)l-00009-of-00010.bin:  89% 2.54G/2.86G [02:26<00:17, 18.3MB/s]
# Downloading (…)l-00009-of-00010.bin:  89% 2.55G/2.86G [02:27<00:17, 17.9MB/s]
# Downloading (…)l-00009-of-00010.bin:  90% 2.56G/2.86G [02:27<00:18, 16.4MB/s]
# Downloading (…)l-00009-of-00010.bin:  90% 2.57G/2.86G [02:28<00:16, 17.7MB/s]
# Downloading (…)l-00009-of-00010.bin:  90% 2.58G/2.86G [02:28<00:15, 17.7MB/s]
# Downloading (…)l-00009-of-00010.bin:  91% 2.59G/2.86G [02:29<00:15, 17.4MB/s]
# Downloading (…)l-00009-of-00010.bin:  91% 2.60G/2.86G [02:30<00:15, 16.9MB/s]
# Downloading (…)l-00009-of-00010.bin:  91% 2.61G/2.86G [02:30<00:14, 17.2MB/s]
# Downloading (…)l-00009-of-00010.bin:  92% 2.62G/2.86G [02:31<00:13, 17.4MB/s]
# Downloading (…)l-00009-of-00010.bin:  92% 2.63G/2.86G [02:32<00:13, 16.8MB/s]
# Downloading (…)l-00009-of-00010.bin:  93% 2.64G/2.86G [02:32<00:12, 17.7MB/s]
# Downloading (…)l-00009-of-00010.bin:  93% 2.65G/2.86G [02:33<00:12, 16.8MB/s]
# Downloading (…)l-00009-of-00010.bin:  93% 2.66G/2.86G [02:33<00:11, 17.1MB/s]
# Downloading (…)l-00009-of-00010.bin:  94% 2.67G/2.86G [02:34<00:09, 18.3MB/s]
# Downloading (…)l-00009-of-00010.bin:  94% 2.68G/2.86G [02:35<00:09, 17.5MB/s]
# Downloading (…)l-00009-of-00010.bin:  94% 2.69G/2.86G [02:35<00:09, 16.8MB/s]
# Downloading (…)l-00009-of-00010.bin:  95% 2.71G/2.86G [02:36<00:08, 18.0MB/s]
# Downloading (…)l-00009-of-00010.bin:  95% 2.72G/2.86G [02:36<00:08, 17.2MB/s]
# Downloading (…)l-00009-of-00010.bin:  95% 2.73G/2.86G [02:37<00:07, 16.7MB/s]
# Downloading (…)l-00009-of-00010.bin:  96% 2.74G/2.86G [02:38<00:06, 18.1MB/s]
# Downloading (…)l-00009-of-00010.bin:  96% 2.75G/2.86G [02:38<00:06, 17.2MB/s]
# Downloading (…)l-00009-of-00010.bin:  97% 2.76G/2.86G [02:39<00:05, 18.3MB/s]
# Downloading (…)l-00009-of-00010.bin:  97% 2.77G/2.86G [02:39<00:05, 17.4MB/s]
# Downloading (…)l-00009-of-00010.bin:  97% 2.78G/2.86G [02:40<00:04, 16.8MB/s]
# Downloading (…)l-00009-of-00010.bin:  98% 2.79G/2.86G [02:41<00:03, 18.2MB/s]
# Downloading (…)l-00009-of-00010.bin:  98% 2.80G/2.86G [02:41<00:03, 17.3MB/s]
# Downloading (…)l-00009-of-00010.bin:  98% 2.81G/2.86G [02:42<00:02, 18.6MB/s]
# Downloading (…)l-00009-of-00010.bin:  99% 2.82G/2.86G [02:42<00:02, 17.5MB/s]
# Downloading (…)l-00009-of-00010.bin:  99% 2.83G/2.86G [02:43<00:01, 16.9MB/s]
# Downloading (…)l-00009-of-00010.bin:  99% 2.84G/2.86G [02:43<00:00, 18.2MB/s]
# Downloading (…)l-00009-of-00010.bin: 100% 2.85G/2.86G [02:44<00:00, 17.3MB/s]
# Downloading (…)l-00009-of-00010.bin: 100% 2.86G/2.86G [02:44<00:00, 17.3MB/s]
# Downloading shards:  90% 9/10 [18:22<02:13, 133.90s/it]
# Downloading (…)l-00010-of-00010.bin:   0% 0.00/705M [00:00<?, ?B/s]
# Downloading (…)l-00010-of-00010.bin:   1% 10.5M/705M [00:02<02:18, 5.01MB/s]
# Downloading (…)l-00010-of-00010.bin:   3% 21.0M/705M [00:02<01:22, 8.33MB/s]
# Downloading (…)l-00010-of-00010.bin:   4% 31.5M/705M [00:03<01:03, 10.6MB/s]
# Downloading (…)l-00010-of-00010.bin:   6% 41.9M/705M [00:03<00:49, 13.3MB/s]
# Downloading (…)l-00010-of-00010.bin:   7% 52.4M/705M [00:04<00:46, 14.0MB/s]
# Downloading (…)l-00010-of-00010.bin:   9% 62.9M/705M [00:05<00:44, 14.5MB/s]
# Downloading (…)l-00010-of-00010.bin:  10% 73.4M/705M [00:05<00:38, 16.3MB/s]
# Downloading (…)l-00010-of-00010.bin:  12% 83.9M/705M [00:06<00:38, 16.1MB/s]
# Downloading (…)l-00010-of-00010.bin:  13% 94.4M/705M [00:07<00:38, 15.9MB/s]
# Downloading (…)l-00010-of-00010.bin:  15% 105M/705M [00:07<00:34, 17.5MB/s]
# Downloading (…)l-00010-of-00010.bin:  16% 115M/705M [00:08<00:35, 16.8MB/s]
# Downloading (…)l-00010-of-00010.bin:  18% 126M/705M [00:08<00:35, 16.3MB/s]
# Downloading (…)l-00010-of-00010.bin:  19% 136M/705M [00:09<00:32, 17.5MB/s]
# Downloading (…)l-00010-of-00010.bin:  21% 147M/705M [00:10<00:32, 17.1MB/s]
# Downloading (…)l-00010-of-00010.bin:  22% 157M/705M [00:10<00:30, 17.9MB/s]
# Downloading (…)l-00010-of-00010.bin:  24% 168M/705M [00:11<00:30, 17.4MB/s]
# Downloading (…)l-00010-of-00010.bin:  25% 178M/705M [00:11<00:31, 16.8MB/s]
# Downloading (…)l-00010-of-00010.bin:  27% 189M/705M [00:12<00:29, 17.6MB/s]
# Downloading (…)l-00010-of-00010.bin:  28% 199M/705M [00:13<00:29, 17.3MB/s]
# Downloading (…)l-00010-of-00010.bin:  30% 210M/705M [00:13<00:29, 16.8MB/s]
# Downloading (…)l-00010-of-00010.bin:  31% 220M/705M [00:14<00:26, 18.1MB/s]
# Downloading (…)l-00010-of-00010.bin:  33% 231M/705M [00:14<00:27, 17.3MB/s]
# Downloading (…)l-00010-of-00010.bin:  34% 241M/705M [00:15<00:25, 18.4MB/s]
# Downloading (…)l-00010-of-00010.bin:  36% 252M/705M [00:16<00:25, 17.5MB/s]
# Downloading (…)l-00010-of-00010.bin:  37% 262M/705M [00:16<00:26, 16.9MB/s]
# Downloading (…)l-00010-of-00010.bin:  39% 273M/705M [00:17<00:23, 18.2MB/s]
# Downloading (…)l-00010-of-00010.bin:  40% 283M/705M [00:17<00:24, 17.2MB/s]
# Downloading (…)l-00010-of-00010.bin:  42% 294M/705M [00:18<00:22, 18.6MB/s]
# Downloading (…)l-00010-of-00010.bin:  43% 304M/705M [00:18<00:22, 17.5MB/s]
# Downloading (…)l-00010-of-00010.bin:  45% 315M/705M [00:19<00:23, 16.8MB/s]
# Downloading (…)l-00010-of-00010.bin:  46% 325M/705M [00:20<00:20, 18.1MB/s]
# Downloading (…)l-00010-of-00010.bin:  48% 336M/705M [00:20<00:21, 17.3MB/s]
# Downloading (…)l-00010-of-00010.bin:  49% 346M/705M [00:21<00:21, 16.6MB/s]
# Downloading (…)l-00010-of-00010.bin:  51% 357M/705M [00:21<00:19, 17.9MB/s]
# Downloading (…)l-00010-of-00010.bin:  52% 367M/705M [00:22<00:19, 17.2MB/s]
# Downloading (…)l-00010-of-00010.bin:  54% 377M/705M [00:23<00:19, 16.6MB/s]
# Downloading (…)l-00010-of-00010.bin:  55% 388M/705M [00:23<00:17, 17.9MB/s]
# Downloading (…)l-00010-of-00010.bin:  57% 398M/705M [00:24<00:18, 16.8MB/s]
# Downloading (…)l-00010-of-00010.bin:  58% 409M/705M [00:25<00:17, 16.6MB/s]
# Downloading (…)l-00010-of-00010.bin:  60% 419M/705M [00:25<00:15, 18.1MB/s]
# Downloading (…)l-00010-of-00010.bin:  61% 430M/705M [00:26<00:16, 17.1MB/s]
# Downloading (…)l-00010-of-00010.bin:  62% 440M/705M [00:27<00:16, 16.3MB/s]
# Downloading (…)l-00010-of-00010.bin:  64% 451M/705M [00:27<00:14, 17.7MB/s]
# Downloading (…)l-00010-of-00010.bin:  65% 461M/705M [00:28<00:14, 16.3MB/s]
# Downloading (…)l-00010-of-00010.bin:  67% 472M/705M [00:28<00:14, 16.1MB/s]
# Downloading (…)l-00010-of-00010.bin:  68% 482M/705M [00:29<00:12, 18.5MB/s]
# Downloading (…)l-00010-of-00010.bin:  70% 493M/705M [00:29<00:12, 17.6MB/s]
# Downloading (…)l-00010-of-00010.bin:  71% 503M/705M [00:30<00:12, 16.8MB/s]
# Downloading (…)l-00010-of-00010.bin:  73% 514M/705M [00:31<00:10, 18.2MB/s]
# Downloading (…)l-00010-of-00010.bin:  74% 524M/705M [00:31<00:10, 17.2MB/s]
# Downloading (…)l-00010-of-00010.bin:  76% 535M/705M [00:32<00:10, 16.7MB/s]
# Downloading (…)l-00010-of-00010.bin:  77% 545M/705M [00:33<00:09, 17.4MB/s]
# Downloading (…)l-00010-of-00010.bin:  79% 556M/705M [00:33<00:08, 17.4MB/s]
# Downloading (…)l-00010-of-00010.bin:  80% 566M/705M [00:34<00:08, 16.7MB/s]
# Downloading (…)l-00010-of-00010.bin:  82% 577M/705M [00:35<00:07, 16.3MB/s]
# Downloading (…)l-00010-of-00010.bin:  83% 587M/705M [00:35<00:06, 17.7MB/s]
# Downloading (…)l-00010-of-00010.bin:  85% 598M/705M [00:36<00:06, 17.0MB/s]
# Downloading (…)l-00010-of-00010.bin:  86% 608M/705M [00:36<00:05, 16.5MB/s]
# Downloading (…)l-00010-of-00010.bin:  88% 619M/705M [00:37<00:05, 16.1MB/s]
# Downloading (…)l-00010-of-00010.bin:  89% 629M/705M [00:38<00:04, 17.6MB/s]
# Downloading (…)l-00010-of-00010.bin:  91% 640M/705M [00:38<00:03, 16.9MB/s]
# Downloading (…)l-00010-of-00010.bin:  92% 650M/705M [00:39<00:02, 18.2MB/s]
# Downloading (…)l-00010-of-00010.bin:  94% 661M/705M [00:39<00:02, 17.3MB/s]
# Downloading (…)l-00010-of-00010.bin:  95% 671M/705M [00:40<00:02, 16.7MB/s]
# Downloading (…)l-00010-of-00010.bin:  97% 682M/705M [00:40<00:01, 18.1MB/s]
# Downloading (…)l-00010-of-00010.bin:  98% 692M/705M [00:41<00:00, 17.2MB/s]
# Downloading (…)l-00010-of-00010.bin: 100% 705M/705M [00:42<00:00, 16.6MB/s]
# Downloading shards: 100% 10/10 [19:07<00:00, 114.75s/it]
# Loading checkpoint shards: 100% 10/10 [02:14<00:00, 13.50s/it]
# Downloading (…)neration_config.json: 100% 174/174 [00:00<00:00, 932kB/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:381: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:386: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# > INFO    Using block size 1024
# Running tokenizer on train dataset: 100% 480/480 [00:00<00:00, 4397.90 examples/s]
# Grouping texts in chunks of 1024 (num_proc=4): 100% 480/480 [00:00<00:00, 2362.50 examples/s]
# > INFO    creating trainer
#   0% 0/12 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.8814, 'learning_rate': 0.0001, 'epoch': 0.25}
# {'loss': 1.3943, 'learning_rate': 0.0002, 'epoch': 0.5}
# {'loss': 1.1417, 'learning_rate': 0.00018, 'epoch': 0.75}
# {'loss': 1.1625, 'learning_rate': 0.00016, 'epoch': 1.0}
#  33% 4/12 [00:46<01:20, 10.05s/it]/usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 1.156, 'learning_rate': 0.00014, 'epoch': 1.25}
# {'loss': 1.0343, 'learning_rate': 0.00012, 'epoch': 1.5}
# {'loss': 1.4754, 'learning_rate': 0.0001, 'epoch': 1.75}
# {'loss': 0.9451, 'learning_rate': 8e-05, 'epoch': 2.0}
#  67% 8/12 [01:32<00:39,  9.99s/it]/usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# {'loss': 0.8884, 'learning_rate': 6e-05, 'epoch': 2.25}
# {'loss': 0.9937, 'learning_rate': 4e-05, 'epoch': 2.5}
# {'loss': 1.2654, 'learning_rate': 2e-05, 'epoch': 2.75}
# {'loss': 0.7745, 'learning_rate': 0.0, 'epoch': 3.0}
# {'train_runtime': 137.7539, 'train_samples_per_second': 0.283, 'train_steps_per_second': 0.087, 'train_loss': 1.1760401924451191, 'epoch': 3.0}
# 100% 12/12 [02:17<00:00, 11.48s/it]
# > INFO    Finished training, saving model...

# %%
# saving the fine-tune training folder
#!zip -r /content/llama2-MJ-prompts.zip /content/llama2-MJ-prompts

# %% [markdown]
# # Inference

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from torch.nn import DataParallel #for multiple gpus

# %%
# accessing the newly fine-tuned model
tokenizer = AutoTokenizer.from_pretrained("/content/llama2-MJ-prompts-v3")
model = AutoModelForCausalLM.from_pretrained("/content/llama2-MJ-prompts-v3")
# Out:
# Loading checkpoint shards:   0%|          | 0/10 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:381: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:386: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(

# %%
input_context = '''
"###Human:
generate a midjourney prompt for a child running in a rain, give a detailed description

####Assistant:
'''

# %% [markdown]
# NB: the `###Assitant:` is empty because the newly fine-tuned model  will be able to generate the prompt.

# %%
input_ids = tokenizer.encode(input_context, return_tensors='pt')

# %%
output = model.generate(input_ids, max_length=85, temperature=0.3, num_return_sequences=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:381: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.3` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(

# %%
generated_text = tokenizer.decode(output[0], skip_special_token=True)
print(generated_text)
# Out:
# <s>
# "###Human:
# generate a midjourney prompt for a child running in a rain, give a detailed description
#
# ####Assistant:
# A child is running in the rain, with a smile on their face. They are wearing a yellow raincoat and blue rain boots. They are holding an umbrella in one hand and a toy in the other. They

# %%
inputs = tokenizer(input_context, return_tensors="pt")
outputs = model.generate(**inputs, num_beams=4, do_sample=True, max_length=85, eos_token_id=tokenizer.eos_token_id)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# "###Human:
# generate a midjourney prompt for a child running in a rain, give a detailed description
#
# ####Assistant:
# The child is running in the rain, wearing a raincoat and holding an umbrella. The rain is falling steadily, and the child is laughing and splashing in the puddles. The child's

# %% [markdown]
# NB:
# - `**inputs`: Unpacks the tokenized input data.
# - `num_beams=4`: Beam search with 4 beams. Provides a trade-off between quality and speed.
# - `do_sample=True`: Sampling is enabled, making the output text more random. It switches the generation mode from deterministic to probabilistic (or stochastic).
# - `max_new_tokens=1024`: The maximum number of tokens for the generated text.

# %% [markdown]
# > **Beam search** is a search algorithm used for finding the most likely sequence of tokens when generating text from a language model. It is  commonly employed in natural language processing tasks like machine translation, text summarization, and text generation.

# %% [markdown]
# # Merging Models and Uploading to HF Hub.
#
# The original model used for fine-tuning is using this class
#
# ```
# from transformers import AutoModelForCausalLM
# ```
#
# > The fine-tuning model has a **`config.json`** file
#
# The resulting fine-tuned model is using this class:
#
#
#
# ```
# from peft import PeftModel
# ```
#
# > The tuned-model has the file **`adapter_config.json`**
#
# The script below will merge both model into a new fine-tuned model and uploading it to the HF hub. Once, done, the model is now ready for production.
#
# The HF task for [inference endpoints](https://ui.endpoints.huggingface.co/royam0820/endpoints) can be used to do that.

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel

# the orginal model used to fine-tuning
base_model_path = "abhishek/llama-2-7b-hf-small-shards"
# the fine-tuned model
adapter_path = "/content/llama2-MJ-prompts-v3"

model = AutoModelForCausalLM.from_pretrained(
    base_model_path,
    torch_dtype=torch.float16,
    low_cpu_mem_usage=True,
)
model = PeftModel.from_pretrained(model, adapter_path)
tokenizer = AutoTokenizer.from_pretrained(base_model_path)
model = model.merge_and_unload()
print('Merge Complete')

hf_repo = "royam0820/my-llm-v1"
access_token = "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"

model.push_to_hub(f"{hf_repo}", use_temp_dir=True, use_auth_token=access_token)
print('Model pushed to Hub')
tokenizer.push_to_hub(f"{hf_repo}", use_temp_dir=True, use_auth_token=access_token)
print('Tokenizer pushed to Hub')
# Out:
# Loading checkpoint shards:   0%|          | 0/10 [00:00<?, ?it/s]
# Merge Complete
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:845: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:527: UserWarning: The generation config instance is invalid -- `.validate()` throws warnings and/or exceptions. Fix these issues to save the configuration. This warning will be raised to an exception in v4.34.
#
# Thrown during validation:
# `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# pytorch_model-00002-of-00003.bin:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# pytorch_model-00001-of-00003.bin:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# pytorch_model-00003-of-00003.bin:   0%|          | 0.00/3.59G [00:00<?, ?B/s]
# Model pushed to Hub
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:845: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Tokenizer pushed to Hub

# %% [markdown]
# # Documentation
# **`model.generate`** method is often used with transformers-based models like those provided by the Hugging Face Transformers library. Below are some commonly used arguments for `model.generate`:
#
# - **`input_ids`**: Tensor containing the token IDs to be fed into the model.
#
# - **`max_length`**: Maximum sequence length for the generated text. The generation will stop once this length is reached.
#
# - **`min_length`**: Minimum sequence length for the generated text. The model will continue generating until this length is reached.
#
# - **`do_sample`**: Whether to sample the next token randomly based on the distribution of the logits (True) or to take the token with the highest logit (False).
#
# - **`temperature`**: Controls the randomness of the token sampling when `do_sample=True`. Higher values make the output more random, while lower values make it more deterministic.
#
# - **`top_k`**: Limits the number of highest-probability tokens considered for sampling. Only relevant when `do_sample=True`.
#
# - **`top_p`**: Also known as "nucleus sampling," this parameter sets a cumulative probability threshold. Tokens with a cumulative probability above this value are excluded from sampling. Only relevant when `do_sample=True`.
#
# - **`num_return_sequences`**: Number of different sequences to generate. Useful for getting multiple outputs for a single input.
#
# - **`pad_token_id`**: Token ID used for padding when the generated sequence is shorter than max_length.
#
# - **`eos_token_id`**: Token ID signaling the end of a sequence. When this token is generated, the sequence will stop.
#
# - **`length_penalty`**: Exponential penalty to apply to the sequence length. Values > 1.0 encourage longer sequences, while values < 1.0 encourage shorter sequences.
#
# - **`early_stopping`**: Whether to stop generation as soon as the end-of-sequence token is generated.
#
# - **`num_beams`**: Number of beams for beam search. Beam search is a technique that explores multiple possibilities in parallel, aiming to find the most probable sequence. Setting this to a value greater than 1 enables beam search.
#
# - **`no_repeat_ngram_size`**: Size of the n-gram window used to prevent repetition of n-grams in the generated text.
#
# - **`bad_words_ids`**: List of token IDs that should not appear in the generated text.
#
# - **`attention_mask`**: Mask to apply to the attention mechanism, typically to ignore padding tokens.
#
# - **`decoder_start_token_id`**:
# Token ID that should be used as the starting token for decoding in sequence-to-sequence models.
#
# Ref.: https://huggingface.co/docs/transformers/main_classes/text_generation

# %% [markdown]
# # Ressources
#
# [Datasets for LLM training](https://github.com/Zjh-819/LLMDataHub) also [HF datasets](https://huggingface.co/datasets)
#
#
# [Model Configuration](https://huggingface.co/docs/transformers/v4.34.1/en/generation_strategies#default-text-generation-configuration)
#
# [OpenAI fine-tuning API](
# https://platform.openai.com/docs/guides/fine-tuning/use-a-fine-tuned-model)
#
# [Introduction to Gradio](https://huggingface.co/learn/nlp-course/chapter9/1?fw=pt)
#
# [HF text generation classes](https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
